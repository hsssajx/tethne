# %%
import tethne.readers as rd
filepath = "../testsuite/testin/cocitations_test_full.txt"
wos_list = rd.wos.parse_wos(filepath)

meta_list=rd.wos.wos2meta(wos_list)

for paper in meta_list:
    for citation in paper['citations']:
        #aug_list= citation['aulast'],' ',  citation['auinit']
        #print paper['citations'][i]['aulast']
        #print aug_list,len(aug_list)
        #print citation['date'],len(citation['auinit'])
        pass

import tethne.networks as nt
author_cocitations = nt.authors.author_cocitation(meta_list, 1
                                                  )
#print author_cocitations.nodes()


import tethne.writers as wr
wr.graph.to_gexf(author_cocitations, "../testsuite/testout/author_cocitations_jan15")

# %%
import tethne.readers as rd
filepath = "../testsuite/testin/iptraffic.txt"
wos_list = rd.wos.parse_wos(filepath)

meta_list=rd.wos.wos2meta(wos_list)

import tethne.networks as nt
author_cocitations = nt.authors.author_cocitation(meta_list, 1)
import tethne.writers as wr
wr.graph.to_gexf(author_cocitations, "../testsuite/testout/author_cocitations_jan15")
# Out:
# Authors Pairs:  ('ANONYMOUS  ', 'ANONYMOUS  ')
# Authors Pairs inv:  ('ANONYMOUS  ', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'ANONYMOUS  ')
# Authors Pairs inv:  ('ANONYMOUS  ', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'ANWER  ')
# Authors Pairs inv:  ('ANWER  ', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'ANWER ')
# Authors Pairs inv:  ('ANWER ', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'BAVIER  ')
# Authors Pairs inv:  ('BAVIER  ', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'BHATIA S.')
# Authors Pairs inv:  ('BHATIA S.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'CAESAR M')
# Authors Pairs inv:  ('CAESAR M', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'CHOWDHURY NMMK')
# Authors Pairs inv:  ('CHOWDHURY NMMK', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'COVINGTON GA')
# Authors Pairs inv:  ('COVINGTON GA', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'DINGLEDINE R')
# Authors Pairs inv:  ('DINGLEDINE R', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'FEAMSTER N.')
# Authors Pairs inv:  ('FEAMSTER N.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'FU J.')
# Authors Pairs inv:  ('FU J.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'GUPTA P')
# Authors Pairs inv:  ('GUPTA P', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'KELLER E.')
# Authors Pairs inv:  ('KELLER E.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'KIM C')
# Authors Pairs inv:  ('KIM C', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'LIAO Y')
# Authors Pairs inv:  ('LIAO Y', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'LIAO YINGCHEN')
# Authors Pairs inv:  ('LIAO YINGCHEN', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'LU GH')
# Authors Pairs inv:  ('LU GH', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'PFAFF B.')
# Authors Pairs inv:  ('PFAFF B.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'RUIZ-SANCHEZ MA')
# Authors Pairs inv:  ('RUIZ-SANCHEZ MA', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'SOLTESZ S.')
# Authors Pairs inv:  ('SOLTESZ S.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'SONG H.')
# Authors Pairs inv:  ('SONG H.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'TURNER J')
# Authors Pairs inv:  ('TURNER J', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'UNNIKRISHNAN D')
# Authors Pairs inv:  ('UNNIKRISHNAN D', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'WANG Y')
# Authors Pairs inv:  ('WANG Y', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'ANONYMOUS  ')
# Authors Pairs inv:  ('ANONYMOUS  ', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'ANWER  ')
# Authors Pairs inv:  ('ANWER  ', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'ANWER ')
# Authors Pairs inv:  ('ANWER ', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'BAVIER  ')
# Authors Pairs inv:  ('BAVIER  ', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'BHATIA S.')
# Authors Pairs inv:  ('BHATIA S.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'CAESAR M')
# Authors Pairs inv:  ('CAESAR M', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'CHOWDHURY NMMK')
# Authors Pairs inv:  ('CHOWDHURY NMMK', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'COVINGTON GA')
# Authors Pairs inv:  ('COVINGTON GA', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'DINGLEDINE R')
# Authors Pairs inv:  ('DINGLEDINE R', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'FEAMSTER N.')
# Authors Pairs inv:  ('FEAMSTER N.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'FU J.')
# Authors Pairs inv:  ('FU J.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'GUPTA P')
# Authors Pairs inv:  ('GUPTA P', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'KELLER E.')
# Authors Pairs inv:  ('KELLER E.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'KIM C')
# Authors Pairs inv:  ('KIM C', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'LIAO Y')
# Authors Pairs inv:  ('LIAO Y', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'LIAO YINGCHEN')
# Authors Pairs inv:  ('LIAO YINGCHEN', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'LU GH')
# Authors Pairs inv:  ('LU GH', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'PFAFF B.')
# Authors Pairs inv:  ('PFAFF B.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'RUIZ-SANCHEZ MA')
# Authors Pairs inv:  ('RUIZ-SANCHEZ MA', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'SOLTESZ S.')
# Authors Pairs inv:  ('SOLTESZ S.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'SONG H.')
# Authors Pairs inv:  ('SONG H.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'TURNER J')
# Authors Pairs inv:  ('TURNER J', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'UNNIKRISHNAN D')
# Authors Pairs inv:  ('UNNIKRISHNAN D', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'WANG Y')
# Authors Pairs inv:  ('WANG Y', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'ANWER  ')
# Authors Pairs inv:  ('ANWER  ', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'ANWER ')
# Authors Pairs inv:  ('ANWER ', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'BAVIER  ')
# Authors Pairs inv:  ('BAVIER  ', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'BHATIA S.')
# Authors Pairs inv:  ('BHATIA S.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'CAESAR M')
# Authors Pairs inv:  ('CAESAR M', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'CHOWDHURY NMMK')
# Authors Pairs inv:  ('CHOWDHURY NMMK', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'COVINGTON GA')
# Authors Pairs inv:  ('COVINGTON GA', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'DINGLEDINE R')
# Authors Pairs inv:  ('DINGLEDINE R', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'FEAMSTER N.')
# Authors Pairs inv:  ('FEAMSTER N.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'FU J.')
# Authors Pairs inv:  ('FU J.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'GUPTA P')
# Authors Pairs inv:  ('GUPTA P', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'KELLER E.')
# Authors Pairs inv:  ('KELLER E.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'KIM C')
# Authors Pairs inv:  ('KIM C', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'LIAO Y')
# Authors Pairs inv:  ('LIAO Y', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'LIAO YINGCHEN')
# Authors Pairs inv:  ('LIAO YINGCHEN', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'LU GH')
# Authors Pairs inv:  ('LU GH', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'PFAFF B.')
# Authors Pairs inv:  ('PFAFF B.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'RUIZ-SANCHEZ MA')
# Authors Pairs inv:  ('RUIZ-SANCHEZ MA', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'SOLTESZ S.')
# Authors Pairs inv:  ('SOLTESZ S.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'SONG H.')
# Authors Pairs inv:  ('SONG H.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'TURNER J')
# Authors Pairs inv:  ('TURNER J', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'UNNIKRISHNAN D')
# Authors Pairs inv:  ('UNNIKRISHNAN D', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'WANG Y')
# Authors Pairs inv:  ('WANG Y', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANONYMOUS  ', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'ANONYMOUS  ')
# Authors Pairs:  ('ANWER  ', 'ANWER ')
# Authors Pairs inv:  ('ANWER ', 'ANWER  ')
# Authors Pairs:  ('ANWER  ', 'BAVIER  ')
# Authors Pairs inv:  ('BAVIER  ', 'ANWER  ')
# Authors Pairs:  ('ANWER  ', 'BHATIA S.')
# Authors Pairs inv:  ('BHATIA S.', 'ANWER  ')
# Authors Pairs:  ('ANWER  ', 'CAESAR M')
# Authors Pairs inv:  ('CAESAR M', 'ANWER  ')
# Authors Pairs:  ('ANWER  ', 'CHOWDHURY NMMK')
# Authors Pairs inv:  ('CHOWDHURY NMMK', 'ANWER  ')
# Authors Pairs:  ('ANWER  ', 'COVINGTON GA')
# Authors Pairs inv:  ('COVINGTON GA', 'ANWER  ')
# Authors Pairs:  ('ANWER  ', 'DINGLEDINE R')
# Authors Pairs inv:  ('DINGLEDINE R', 'ANWER  ')
# Authors Pairs:  ('ANWER  ', 'FEAMSTER N.')
# Authors Pairs inv:  ('FEAMSTER N.', 'ANWER  ')
# Authors Pairs:  ('ANWER  ', 'FU J.')
# Authors Pairs inv:  ('FU J.', 'ANWER  ')
# Authors Pairs:  ('ANWER  ', 'GUPTA P')
# Authors Pairs inv:  ('GUPTA P', 'ANWER  ')
# Authors Pairs:  ('ANWER  ', 'KELLER E.')
# Authors Pairs inv:  ('KELLER E.', 'ANWER  ')
# Authors Pairs:  ('ANWER  ', 'KIM C')
# Authors Pairs inv:  ('KIM C', 'ANWER  ')
# Authors Pairs:  ('ANWER  ', 'LIAO Y')
# Authors Pairs inv:  ('LIAO Y', 'ANWER  ')
# Authors Pairs:  ('ANWER  ', 'LIAO YINGCHEN')
# Authors Pairs inv:  ('LIAO YINGCHEN', 'ANWER  ')
# Authors Pairs:  ('ANWER  ', 'LU GH')
# Authors Pairs inv:  ('LU GH', 'ANWER  ')
# Authors Pairs:  ('ANWER  ', 'PFAFF B.')
# Authors Pairs inv:  ('PFAFF B.', 'ANWER  ')
# Authors Pairs:  ('ANWER  ', 'RUIZ-SANCHEZ MA')
# Authors Pairs inv:  ('RUIZ-SANCHEZ MA', 'ANWER  ')
# Authors Pairs:  ('ANWER  ', 'SOLTESZ S.')
# Authors Pairs inv:  ('SOLTESZ S.', 'ANWER  ')
# Authors Pairs:  ('ANWER  ', 'SONG H.')
# Authors Pairs inv:  ('SONG H.', 'ANWER  ')
# Authors Pairs:  ('ANWER  ', 'TURNER J')
# Authors Pairs inv:  ('TURNER J', 'ANWER  ')
# Authors Pairs:  ('ANWER  ', 'UNNIKRISHNAN D')
# Authors Pairs inv:  ('UNNIKRISHNAN D', 'ANWER  ')
# Authors Pairs:  ('ANWER  ', 'WANG Y')
# Authors Pairs inv:  ('WANG Y', 'ANWER  ')
# Authors Pairs:  ('ANWER  ', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'ANWER  ')
# Authors Pairs:  ('ANWER  ', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'ANWER  ')
# Authors Pairs:  ('ANWER ', 'BAVIER  ')
# Authors Pairs inv:  ('BAVIER  ', 'ANWER ')
# Authors Pairs:  ('ANWER ', 'BHATIA S.')
# Authors Pairs inv:  ('BHATIA S.', 'ANWER ')
# Authors Pairs:  ('ANWER ', 'CAESAR M')
# Authors Pairs inv:  ('CAESAR M', 'ANWER ')
# Authors Pairs:  ('ANWER ', 'CHOWDHURY NMMK')
# Authors Pairs inv:  ('CHOWDHURY NMMK', 'ANWER ')
# Authors Pairs:  ('ANWER ', 'COVINGTON GA')
# Authors Pairs inv:  ('COVINGTON GA', 'ANWER ')
# Authors Pairs:  ('ANWER ', 'DINGLEDINE R')
# Authors Pairs inv:  ('DINGLEDINE R', 'ANWER ')
# Authors Pairs:  ('ANWER ', 'FEAMSTER N.')
# Authors Pairs inv:  ('FEAMSTER N.', 'ANWER ')
# Authors Pairs:  ('ANWER ', 'FU J.')
# Authors Pairs inv:  ('FU J.', 'ANWER ')
# Authors Pairs:  ('ANWER ', 'GUPTA P')
# Authors Pairs inv:  ('GUPTA P', 'ANWER ')
# Authors Pairs:  ('ANWER ', 'KELLER E.')
# Authors Pairs inv:  ('KELLER E.', 'ANWER ')
# Authors Pairs:  ('ANWER ', 'KIM C')
# Authors Pairs inv:  ('KIM C', 'ANWER ')
# Authors Pairs:  ('ANWER ', 'LIAO Y')
# Authors Pairs inv:  ('LIAO Y', 'ANWER ')
# Authors Pairs:  ('ANWER ', 'LIAO YINGCHEN')
# Authors Pairs inv:  ('LIAO YINGCHEN', 'ANWER ')
# Authors Pairs:  ('ANWER ', 'LU GH')
# Authors Pairs inv:  ('LU GH', 'ANWER ')
# Authors Pairs:  ('ANWER ', 'PFAFF B.')
# Authors Pairs inv:  ('PFAFF B.', 'ANWER ')
# Authors Pairs:  ('ANWER ', 'RUIZ-SANCHEZ MA')
# Authors Pairs inv:  ('RUIZ-SANCHEZ MA', 'ANWER ')
# Authors Pairs:  ('ANWER ', 'SOLTESZ S.')
# Authors Pairs inv:  ('SOLTESZ S.', 'ANWER ')
# Authors Pairs:  ('ANWER ', 'SONG H.')
# Authors Pairs inv:  ('SONG H.', 'ANWER ')
# Authors Pairs:  ('ANWER ', 'TURNER J')
# Authors Pairs inv:  ('TURNER J', 'ANWER ')
# Authors Pairs:  ('ANWER ', 'UNNIKRISHNAN D')
# Authors Pairs inv:  ('UNNIKRISHNAN D', 'ANWER ')
# Authors Pairs:  ('ANWER ', 'WANG Y')
# Authors Pairs inv:  ('WANG Y', 'ANWER ')
# Authors Pairs:  ('ANWER ', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'ANWER ')
# Authors Pairs:  ('ANWER ', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'ANWER ')
# Authors Pairs:  ('BAVIER  ', 'BHATIA S.')
# Authors Pairs inv:  ('BHATIA S.', 'BAVIER  ')
# Authors Pairs:  ('BAVIER  ', 'CAESAR M')
# Authors Pairs inv:  ('CAESAR M', 'BAVIER  ')
# Authors Pairs:  ('BAVIER  ', 'CHOWDHURY NMMK')
# Authors Pairs inv:  ('CHOWDHURY NMMK', 'BAVIER  ')
# Authors Pairs:  ('BAVIER  ', 'COVINGTON GA')
# Authors Pairs inv:  ('COVINGTON GA', 'BAVIER  ')
# Authors Pairs:  ('BAVIER  ', 'DINGLEDINE R')
# Authors Pairs inv:  ('DINGLEDINE R', 'BAVIER  ')
# Authors Pairs:  ('BAVIER  ', 'FEAMSTER N.')
# Authors Pairs inv:  ('FEAMSTER N.', 'BAVIER  ')
# Authors Pairs:  ('BAVIER  ', 'FU J.')
# Authors Pairs inv:  ('FU J.', 'BAVIER  ')
# Authors Pairs:  ('BAVIER  ', 'GUPTA P')
# Authors Pairs inv:  ('GUPTA P', 'BAVIER  ')
# Authors Pairs:  ('BAVIER  ', 'KELLER E.')
# Authors Pairs inv:  ('KELLER E.', 'BAVIER  ')
# Authors Pairs:  ('BAVIER  ', 'KIM C')
# Authors Pairs inv:  ('KIM C', 'BAVIER  ')
# Authors Pairs:  ('BAVIER  ', 'LIAO Y')
# Authors Pairs inv:  ('LIAO Y', 'BAVIER  ')
# Authors Pairs:  ('BAVIER  ', 'LIAO YINGCHEN')
# Authors Pairs inv:  ('LIAO YINGCHEN', 'BAVIER  ')
# Authors Pairs:  ('BAVIER  ', 'LU GH')
# Authors Pairs inv:  ('LU GH', 'BAVIER  ')
# Authors Pairs:  ('BAVIER  ', 'PFAFF B.')
# Authors Pairs inv:  ('PFAFF B.', 'BAVIER  ')
# Authors Pairs:  ('BAVIER  ', 'RUIZ-SANCHEZ MA')
# Authors Pairs inv:  ('RUIZ-SANCHEZ MA', 'BAVIER  ')
# Authors Pairs:  ('BAVIER  ', 'SOLTESZ S.')
# Authors Pairs inv:  ('SOLTESZ S.', 'BAVIER  ')
# Authors Pairs:  ('BAVIER  ', 'SONG H.')
# Authors Pairs inv:  ('SONG H.', 'BAVIER  ')
# Authors Pairs:  ('BAVIER  ', 'TURNER J')
# Authors Pairs inv:  ('TURNER J', 'BAVIER  ')
# Authors Pairs:  ('BAVIER  ', 'UNNIKRISHNAN D')
# Authors Pairs inv:  ('UNNIKRISHNAN D', 'BAVIER  ')
# Authors Pairs:  ('BAVIER  ', 'WANG Y')
# Authors Pairs inv:  ('WANG Y', 'BAVIER  ')
# Authors Pairs:  ('BAVIER  ', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'BAVIER  ')
# Authors Pairs:  ('BAVIER  ', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'BAVIER  ')
# Authors Pairs:  ('BHATIA S.', 'CAESAR M')
# Authors Pairs inv:  ('CAESAR M', 'BHATIA S.')
# Authors Pairs:  ('BHATIA S.', 'CHOWDHURY NMMK')
# Authors Pairs inv:  ('CHOWDHURY NMMK', 'BHATIA S.')
# Authors Pairs:  ('BHATIA S.', 'COVINGTON GA')
# Authors Pairs inv:  ('COVINGTON GA', 'BHATIA S.')
# Authors Pairs:  ('BHATIA S.', 'DINGLEDINE R')
# Authors Pairs inv:  ('DINGLEDINE R', 'BHATIA S.')
# Authors Pairs:  ('BHATIA S.', 'FEAMSTER N.')
# Authors Pairs inv:  ('FEAMSTER N.', 'BHATIA S.')
# Authors Pairs:  ('BHATIA S.', 'FU J.')
# Authors Pairs inv:  ('FU J.', 'BHATIA S.')
# Authors Pairs:  ('BHATIA S.', 'GUPTA P')
# Authors Pairs inv:  ('GUPTA P', 'BHATIA S.')
# Authors Pairs:  ('BHATIA S.', 'KELLER E.')
# Authors Pairs inv:  ('KELLER E.', 'BHATIA S.')
# Authors Pairs:  ('BHATIA S.', 'KIM C')
# Authors Pairs inv:  ('KIM C', 'BHATIA S.')
# Authors Pairs:  ('BHATIA S.', 'LIAO Y')
# Authors Pairs inv:  ('LIAO Y', 'BHATIA S.')
# Authors Pairs:  ('BHATIA S.', 'LIAO YINGCHEN')
# Authors Pairs inv:  ('LIAO YINGCHEN', 'BHATIA S.')
# Authors Pairs:  ('BHATIA S.', 'LU GH')
# Authors Pairs inv:  ('LU GH', 'BHATIA S.')
# Authors Pairs:  ('BHATIA S.', 'PFAFF B.')
# Authors Pairs inv:  ('PFAFF B.', 'BHATIA S.')
# Authors Pairs:  ('BHATIA S.', 'RUIZ-SANCHEZ MA')
# Authors Pairs inv:  ('RUIZ-SANCHEZ MA', 'BHATIA S.')
# Authors Pairs:  ('BHATIA S.', 'SOLTESZ S.')
# Authors Pairs inv:  ('SOLTESZ S.', 'BHATIA S.')
# Authors Pairs:  ('BHATIA S.', 'SONG H.')
# Authors Pairs inv:  ('SONG H.', 'BHATIA S.')
# Authors Pairs:  ('BHATIA S.', 'TURNER J')
# Authors Pairs inv:  ('TURNER J', 'BHATIA S.')
# Authors Pairs:  ('BHATIA S.', 'UNNIKRISHNAN D')
# Authors Pairs inv:  ('UNNIKRISHNAN D', 'BHATIA S.')
# Authors Pairs:  ('BHATIA S.', 'WANG Y')
# Authors Pairs inv:  ('WANG Y', 'BHATIA S.')
# Authors Pairs:  ('BHATIA S.', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'BHATIA S.')
# Authors Pairs:  ('BHATIA S.', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'BHATIA S.')
# Authors Pairs:  ('CAESAR M', 'CHOWDHURY NMMK')
# Authors Pairs inv:  ('CHOWDHURY NMMK', 'CAESAR M')
# Authors Pairs:  ('CAESAR M', 'COVINGTON GA')
# Authors Pairs inv:  ('COVINGTON GA', 'CAESAR M')
# Authors Pairs:  ('CAESAR M', 'DINGLEDINE R')
# Authors Pairs inv:  ('DINGLEDINE R', 'CAESAR M')
# Authors Pairs:  ('CAESAR M', 'FEAMSTER N.')
# Authors Pairs inv:  ('FEAMSTER N.', 'CAESAR M')
# Authors Pairs:  ('CAESAR M', 'FU J.')
# Authors Pairs inv:  ('FU J.', 'CAESAR M')
# Authors Pairs:  ('CAESAR M', 'GUPTA P')
# Authors Pairs inv:  ('GUPTA P', 'CAESAR M')
# Authors Pairs:  ('CAESAR M', 'KELLER E.')
# Authors Pairs inv:  ('KELLER E.', 'CAESAR M')
# Authors Pairs:  ('CAESAR M', 'KIM C')
# Authors Pairs inv:  ('KIM C', 'CAESAR M')
# Authors Pairs:  ('CAESAR M', 'LIAO Y')
# Authors Pairs inv:  ('LIAO Y', 'CAESAR M')
# Authors Pairs:  ('CAESAR M', 'LIAO YINGCHEN')
# Authors Pairs inv:  ('LIAO YINGCHEN', 'CAESAR M')
# Authors Pairs:  ('CAESAR M', 'LU GH')
# Authors Pairs inv:  ('LU GH', 'CAESAR M')
# Authors Pairs:  ('CAESAR M', 'PFAFF B.')
# Authors Pairs inv:  ('PFAFF B.', 'CAESAR M')
# Authors Pairs:  ('CAESAR M', 'RUIZ-SANCHEZ MA')
# Authors Pairs inv:  ('RUIZ-SANCHEZ MA', 'CAESAR M')
# Authors Pairs:  ('CAESAR M', 'SOLTESZ S.')
# Authors Pairs inv:  ('SOLTESZ S.', 'CAESAR M')
# Authors Pairs:  ('CAESAR M', 'SONG H.')
# Authors Pairs inv:  ('SONG H.', 'CAESAR M')
# Authors Pairs:  ('CAESAR M', 'TURNER J')
# Authors Pairs inv:  ('TURNER J', 'CAESAR M')
# Authors Pairs:  ('CAESAR M', 'UNNIKRISHNAN D')
# Authors Pairs inv:  ('UNNIKRISHNAN D', 'CAESAR M')
# Authors Pairs:  ('CAESAR M', 'WANG Y')
# Authors Pairs inv:  ('WANG Y', 'CAESAR M')
# Authors Pairs:  ('CAESAR M', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'CAESAR M')
# Authors Pairs:  ('CAESAR M', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'CAESAR M')
# Authors Pairs:  ('CHOWDHURY NMMK', 'COVINGTON GA')
# Authors Pairs inv:  ('COVINGTON GA', 'CHOWDHURY NMMK')
# Authors Pairs:  ('CHOWDHURY NMMK', 'DINGLEDINE R')
# Authors Pairs inv:  ('DINGLEDINE R', 'CHOWDHURY NMMK')
# Authors Pairs:  ('CHOWDHURY NMMK', 'FEAMSTER N.')
# Authors Pairs inv:  ('FEAMSTER N.', 'CHOWDHURY NMMK')
# Authors Pairs:  ('CHOWDHURY NMMK', 'FU J.')
# Authors Pairs inv:  ('FU J.', 'CHOWDHURY NMMK')
# Authors Pairs:  ('CHOWDHURY NMMK', 'GUPTA P')
# Authors Pairs inv:  ('GUPTA P', 'CHOWDHURY NMMK')
# Authors Pairs:  ('CHOWDHURY NMMK', 'KELLER E.')
# Authors Pairs inv:  ('KELLER E.', 'CHOWDHURY NMMK')
# Authors Pairs:  ('CHOWDHURY NMMK', 'KIM C')
# Authors Pairs inv:  ('KIM C', 'CHOWDHURY NMMK')
# Authors Pairs:  ('CHOWDHURY NMMK', 'LIAO Y')
# Authors Pairs inv:  ('LIAO Y', 'CHOWDHURY NMMK')
# Authors Pairs:  ('CHOWDHURY NMMK', 'LIAO YINGCHEN')
# Authors Pairs inv:  ('LIAO YINGCHEN', 'CHOWDHURY NMMK')
# Authors Pairs:  ('CHOWDHURY NMMK', 'LU GH')
# Authors Pairs inv:  ('LU GH', 'CHOWDHURY NMMK')
# Authors Pairs:  ('CHOWDHURY NMMK', 'PFAFF B.')
# Authors Pairs inv:  ('PFAFF B.', 'CHOWDHURY NMMK')
# Authors Pairs:  ('CHOWDHURY NMMK', 'RUIZ-SANCHEZ MA')
# Authors Pairs inv:  ('RUIZ-SANCHEZ MA', 'CHOWDHURY NMMK')
# Authors Pairs:  ('CHOWDHURY NMMK', 'SOLTESZ S.')
# Authors Pairs inv:  ('SOLTESZ S.', 'CHOWDHURY NMMK')
# Authors Pairs:  ('CHOWDHURY NMMK', 'SONG H.')
# Authors Pairs inv:  ('SONG H.', 'CHOWDHURY NMMK')
# Authors Pairs:  ('CHOWDHURY NMMK', 'TURNER J')
# Authors Pairs inv:  ('TURNER J', 'CHOWDHURY NMMK')
# Authors Pairs:  ('CHOWDHURY NMMK', 'UNNIKRISHNAN D')
# Authors Pairs inv:  ('UNNIKRISHNAN D', 'CHOWDHURY NMMK')
# Authors Pairs:  ('CHOWDHURY NMMK', 'WANG Y')
# Authors Pairs inv:  ('WANG Y', 'CHOWDHURY NMMK')
# Authors Pairs:  ('CHOWDHURY NMMK', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'CHOWDHURY NMMK')
# Authors Pairs:  ('CHOWDHURY NMMK', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'CHOWDHURY NMMK')
# Authors Pairs:  ('COVINGTON GA', 'DINGLEDINE R')
# Authors Pairs inv:  ('DINGLEDINE R', 'COVINGTON GA')
# Authors Pairs:  ('COVINGTON GA', 'FEAMSTER N.')
# Authors Pairs inv:  ('FEAMSTER N.', 'COVINGTON GA')
# Authors Pairs:  ('COVINGTON GA', 'FU J.')
# Authors Pairs inv:  ('FU J.', 'COVINGTON GA')
# Authors Pairs:  ('COVINGTON GA', 'GUPTA P')
# Authors Pairs inv:  ('GUPTA P', 'COVINGTON GA')
# Authors Pairs:  ('COVINGTON GA', 'KELLER E.')
# Authors Pairs inv:  ('KELLER E.', 'COVINGTON GA')
# Authors Pairs:  ('COVINGTON GA', 'KIM C')
# Authors Pairs inv:  ('KIM C', 'COVINGTON GA')
# Authors Pairs:  ('COVINGTON GA', 'LIAO Y')
# Authors Pairs inv:  ('LIAO Y', 'COVINGTON GA')
# Authors Pairs:  ('COVINGTON GA', 'LIAO YINGCHEN')
# Authors Pairs inv:  ('LIAO YINGCHEN', 'COVINGTON GA')
# Authors Pairs:  ('COVINGTON GA', 'LU GH')
# Authors Pairs inv:  ('LU GH', 'COVINGTON GA')
# Authors Pairs:  ('COVINGTON GA', 'PFAFF B.')
# Authors Pairs inv:  ('PFAFF B.', 'COVINGTON GA')
# Authors Pairs:  ('COVINGTON GA', 'RUIZ-SANCHEZ MA')
# Authors Pairs inv:  ('RUIZ-SANCHEZ MA', 'COVINGTON GA')
# Authors Pairs:  ('COVINGTON GA', 'SOLTESZ S.')
# Authors Pairs inv:  ('SOLTESZ S.', 'COVINGTON GA')
# Authors Pairs:  ('COVINGTON GA', 'SONG H.')
# Authors Pairs inv:  ('SONG H.', 'COVINGTON GA')
# Authors Pairs:  ('COVINGTON GA', 'TURNER J')
# Authors Pairs inv:  ('TURNER J', 'COVINGTON GA')
# Authors Pairs:  ('COVINGTON GA', 'UNNIKRISHNAN D')
# Authors Pairs inv:  ('UNNIKRISHNAN D', 'COVINGTON GA')
# Authors Pairs:  ('COVINGTON GA', 'WANG Y')
# Authors Pairs inv:  ('WANG Y', 'COVINGTON GA')
# Authors Pairs:  ('COVINGTON GA', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'COVINGTON GA')
# Authors Pairs:  ('COVINGTON GA', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'COVINGTON GA')
# Authors Pairs:  ('DINGLEDINE R', 'FEAMSTER N.')
# Authors Pairs inv:  ('FEAMSTER N.', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'FU J.')
# Authors Pairs inv:  ('FU J.', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'GUPTA P')
# Authors Pairs inv:  ('GUPTA P', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'KELLER E.')
# Authors Pairs inv:  ('KELLER E.', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'KIM C')
# Authors Pairs inv:  ('KIM C', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'LIAO Y')
# Authors Pairs inv:  ('LIAO Y', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'LIAO YINGCHEN')
# Authors Pairs inv:  ('LIAO YINGCHEN', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'LU GH')
# Authors Pairs inv:  ('LU GH', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'PFAFF B.')
# Authors Pairs inv:  ('PFAFF B.', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'RUIZ-SANCHEZ MA')
# Authors Pairs inv:  ('RUIZ-SANCHEZ MA', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'SOLTESZ S.')
# Authors Pairs inv:  ('SOLTESZ S.', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'SONG H.')
# Authors Pairs inv:  ('SONG H.', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'TURNER J')
# Authors Pairs inv:  ('TURNER J', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'UNNIKRISHNAN D')
# Authors Pairs inv:  ('UNNIKRISHNAN D', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'WANG Y')
# Authors Pairs inv:  ('WANG Y', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'DINGLEDINE R')
# Authors Pairs:  ('FEAMSTER N.', 'FU J.')
# Authors Pairs inv:  ('FU J.', 'FEAMSTER N.')
# Authors Pairs:  ('FEAMSTER N.', 'GUPTA P')
# Authors Pairs inv:  ('GUPTA P', 'FEAMSTER N.')
# Authors Pairs:  ('FEAMSTER N.', 'KELLER E.')
# Authors Pairs inv:  ('KELLER E.', 'FEAMSTER N.')
# Authors Pairs:  ('FEAMSTER N.', 'KIM C')
# Authors Pairs inv:  ('KIM C', 'FEAMSTER N.')
# Authors Pairs:  ('FEAMSTER N.', 'LIAO Y')
# Authors Pairs inv:  ('LIAO Y', 'FEAMSTER N.')
# Authors Pairs:  ('FEAMSTER N.', 'LIAO YINGCHEN')
# Authors Pairs inv:  ('LIAO YINGCHEN', 'FEAMSTER N.')
# Authors Pairs:  ('FEAMSTER N.', 'LU GH')
# Authors Pairs inv:  ('LU GH', 'FEAMSTER N.')
# Authors Pairs:  ('FEAMSTER N.', 'PFAFF B.')
# Authors Pairs inv:  ('PFAFF B.', 'FEAMSTER N.')
# Authors Pairs:  ('FEAMSTER N.', 'RUIZ-SANCHEZ MA')
# Authors Pairs inv:  ('RUIZ-SANCHEZ MA', 'FEAMSTER N.')
# Authors Pairs:  ('FEAMSTER N.', 'SOLTESZ S.')
# Authors Pairs inv:  ('SOLTESZ S.', 'FEAMSTER N.')
# Authors Pairs:  ('FEAMSTER N.', 'SONG H.')
# Authors Pairs inv:  ('SONG H.', 'FEAMSTER N.')
# Authors Pairs:  ('FEAMSTER N.', 'TURNER J')
# Authors Pairs inv:  ('TURNER J', 'FEAMSTER N.')
# Authors Pairs:  ('FEAMSTER N.', 'UNNIKRISHNAN D')
# Authors Pairs inv:  ('UNNIKRISHNAN D', 'FEAMSTER N.')
# Authors Pairs:  ('FEAMSTER N.', 'WANG Y')
# Authors Pairs inv:  ('WANG Y', 'FEAMSTER N.')
# Authors Pairs:  ('FEAMSTER N.', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'FEAMSTER N.')
# Authors Pairs:  ('FEAMSTER N.', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'FEAMSTER N.')
# Authors Pairs:  ('FU J.', 'GUPTA P')
# Authors Pairs inv:  ('GUPTA P', 'FU J.')
# Authors Pairs:  ('FU J.', 'KELLER E.')
# Authors Pairs inv:  ('KELLER E.', 'FU J.')
# Authors Pairs:  ('FU J.', 'KIM C')
# Authors Pairs inv:  ('KIM C', 'FU J.')
# Authors Pairs:  ('FU J.', 'LIAO Y')
# Authors Pairs inv:  ('LIAO Y', 'FU J.')
# Authors Pairs:  ('FU J.', 'LIAO YINGCHEN')
# Authors Pairs inv:  ('LIAO YINGCHEN', 'FU J.')
# Authors Pairs:  ('FU J.', 'LU GH')
# Authors Pairs inv:  ('LU GH', 'FU J.')
# Authors Pairs:  ('FU J.', 'PFAFF B.')
# Authors Pairs inv:  ('PFAFF B.', 'FU J.')
# Authors Pairs:  ('FU J.', 'RUIZ-SANCHEZ MA')
# Authors Pairs inv:  ('RUIZ-SANCHEZ MA', 'FU J.')
# Authors Pairs:  ('FU J.', 'SOLTESZ S.')
# Authors Pairs inv:  ('SOLTESZ S.', 'FU J.')
# Authors Pairs:  ('FU J.', 'SONG H.')
# Authors Pairs inv:  ('SONG H.', 'FU J.')
# Authors Pairs:  ('FU J.', 'TURNER J')
# Authors Pairs inv:  ('TURNER J', 'FU J.')
# Authors Pairs:  ('FU J.', 'UNNIKRISHNAN D')
# Authors Pairs inv:  ('UNNIKRISHNAN D', 'FU J.')
# Authors Pairs:  ('FU J.', 'WANG Y')
# Authors Pairs inv:  ('WANG Y', 'FU J.')
# Authors Pairs:  ('FU J.', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'FU J.')
# Authors Pairs:  ('FU J.', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'FU J.')
# Authors Pairs:  ('GUPTA P', 'KELLER E.')
# Authors Pairs inv:  ('KELLER E.', 'GUPTA P')
# Authors Pairs:  ('GUPTA P', 'KIM C')
# Authors Pairs inv:  ('KIM C', 'GUPTA P')
# Authors Pairs:  ('GUPTA P', 'LIAO Y')
# Authors Pairs inv:  ('LIAO Y', 'GUPTA P')
# Authors Pairs:  ('GUPTA P', 'LIAO YINGCHEN')
# Authors Pairs inv:  ('LIAO YINGCHEN', 'GUPTA P')
# Authors Pairs:  ('GUPTA P', 'LU GH')
# Authors Pairs inv:  ('LU GH', 'GUPTA P')
# Authors Pairs:  ('GUPTA P', 'PFAFF B.')
# Authors Pairs inv:  ('PFAFF B.', 'GUPTA P')
# Authors Pairs:  ('GUPTA P', 'RUIZ-SANCHEZ MA')
# Authors Pairs inv:  ('RUIZ-SANCHEZ MA', 'GUPTA P')
# Authors Pairs:  ('GUPTA P', 'SOLTESZ S.')
# Authors Pairs inv:  ('SOLTESZ S.', 'GUPTA P')
# Authors Pairs:  ('GUPTA P', 'SONG H.')
# Authors Pairs inv:  ('SONG H.', 'GUPTA P')
# Authors Pairs:  ('GUPTA P', 'TURNER J')
# Authors Pairs inv:  ('TURNER J', 'GUPTA P')
# Authors Pairs:  ('GUPTA P', 'UNNIKRISHNAN D')
# Authors Pairs inv:  ('UNNIKRISHNAN D', 'GUPTA P')
# Authors Pairs:  ('GUPTA P', 'WANG Y')
# Authors Pairs inv:  ('WANG Y', 'GUPTA P')
# Authors Pairs:  ('GUPTA P', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'GUPTA P')
# Authors Pairs:  ('GUPTA P', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'GUPTA P')
# Authors Pairs:  ('KELLER E.', 'KIM C')
# Authors Pairs inv:  ('KIM C', 'KELLER E.')
# Authors Pairs:  ('KELLER E.', 'LIAO Y')
# Authors Pairs inv:  ('LIAO Y', 'KELLER E.')
# Authors Pairs:  ('KELLER E.', 'LIAO YINGCHEN')
# Authors Pairs inv:  ('LIAO YINGCHEN', 'KELLER E.')
# Authors Pairs:  ('KELLER E.', 'LU GH')
# Authors Pairs inv:  ('LU GH', 'KELLER E.')
# Authors Pairs:  ('KELLER E.', 'PFAFF B.')
# Authors Pairs inv:  ('PFAFF B.', 'KELLER E.')
# Authors Pairs:  ('KELLER E.', 'RUIZ-SANCHEZ MA')
# Authors Pairs inv:  ('RUIZ-SANCHEZ MA', 'KELLER E.')
# Authors Pairs:  ('KELLER E.', 'SOLTESZ S.')
# Authors Pairs inv:  ('SOLTESZ S.', 'KELLER E.')
# Authors Pairs:  ('KELLER E.', 'SONG H.')
# Authors Pairs inv:  ('SONG H.', 'KELLER E.')
# Authors Pairs:  ('KELLER E.', 'TURNER J')
# Authors Pairs inv:  ('TURNER J', 'KELLER E.')
# Authors Pairs:  ('KELLER E.', 'UNNIKRISHNAN D')
# Authors Pairs inv:  ('UNNIKRISHNAN D', 'KELLER E.')
# Authors Pairs:  ('KELLER E.', 'WANG Y')
# Authors Pairs inv:  ('WANG Y', 'KELLER E.')
# Authors Pairs:  ('KELLER E.', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'KELLER E.')
# Authors Pairs:  ('KELLER E.', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'KELLER E.')
# Authors Pairs:  ('KIM C', 'LIAO Y')
# Authors Pairs inv:  ('LIAO Y', 'KIM C')
# Authors Pairs:  ('KIM C', 'LIAO YINGCHEN')
# Authors Pairs inv:  ('LIAO YINGCHEN', 'KIM C')
# Authors Pairs:  ('KIM C', 'LU GH')
# Authors Pairs inv:  ('LU GH', 'KIM C')
# Authors Pairs:  ('KIM C', 'PFAFF B.')
# Authors Pairs inv:  ('PFAFF B.', 'KIM C')
# Authors Pairs:  ('KIM C', 'RUIZ-SANCHEZ MA')
# Authors Pairs inv:  ('RUIZ-SANCHEZ MA', 'KIM C')
# Authors Pairs:  ('KIM C', 'SOLTESZ S.')
# Authors Pairs inv:  ('SOLTESZ S.', 'KIM C')
# Authors Pairs:  ('KIM C', 'SONG H.')
# Authors Pairs inv:  ('SONG H.', 'KIM C')
# Authors Pairs:  ('KIM C', 'TURNER J')
# Authors Pairs inv:  ('TURNER J', 'KIM C')
# Authors Pairs:  ('KIM C', 'UNNIKRISHNAN D')
# Authors Pairs inv:  ('UNNIKRISHNAN D', 'KIM C')
# Authors Pairs:  ('KIM C', 'WANG Y')
# Authors Pairs inv:  ('WANG Y', 'KIM C')
# Authors Pairs:  ('KIM C', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'KIM C')
# Authors Pairs:  ('KIM C', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'KIM C')
# Authors Pairs:  ('LIAO Y', 'LIAO YINGCHEN')
# Authors Pairs inv:  ('LIAO YINGCHEN', 'LIAO Y')
# Authors Pairs:  ('LIAO Y', 'LU GH')
# Authors Pairs inv:  ('LU GH', 'LIAO Y')
# Authors Pairs:  ('LIAO Y', 'PFAFF B.')
# Authors Pairs inv:  ('PFAFF B.', 'LIAO Y')
# Authors Pairs:  ('LIAO Y', 'RUIZ-SANCHEZ MA')
# Authors Pairs inv:  ('RUIZ-SANCHEZ MA', 'LIAO Y')
# Authors Pairs:  ('LIAO Y', 'SOLTESZ S.')
# Authors Pairs inv:  ('SOLTESZ S.', 'LIAO Y')
# Authors Pairs:  ('LIAO Y', 'SONG H.')
# Authors Pairs inv:  ('SONG H.', 'LIAO Y')
# Authors Pairs:  ('LIAO Y', 'TURNER J')
# Authors Pairs inv:  ('TURNER J', 'LIAO Y')
# Authors Pairs:  ('LIAO Y', 'UNNIKRISHNAN D')
# Authors Pairs inv:  ('UNNIKRISHNAN D', 'LIAO Y')
# Authors Pairs:  ('LIAO Y', 'WANG Y')
# Authors Pairs inv:  ('WANG Y', 'LIAO Y')
# Authors Pairs:  ('LIAO Y', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'LIAO Y')
# Authors Pairs:  ('LIAO Y', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'LIAO Y')
# Authors Pairs:  ('LIAO YINGCHEN', 'LU GH')
# Authors Pairs inv:  ('LU GH', 'LIAO YINGCHEN')
# Authors Pairs:  ('LIAO YINGCHEN', 'PFAFF B.')
# Authors Pairs inv:  ('PFAFF B.', 'LIAO YINGCHEN')
# Authors Pairs:  ('LIAO YINGCHEN', 'RUIZ-SANCHEZ MA')
# Authors Pairs inv:  ('RUIZ-SANCHEZ MA', 'LIAO YINGCHEN')
# Authors Pairs:  ('LIAO YINGCHEN', 'SOLTESZ S.')
# Authors Pairs inv:  ('SOLTESZ S.', 'LIAO YINGCHEN')
# Authors Pairs:  ('LIAO YINGCHEN', 'SONG H.')
# Authors Pairs inv:  ('SONG H.', 'LIAO YINGCHEN')
# Authors Pairs:  ('LIAO YINGCHEN', 'TURNER J')
# Authors Pairs inv:  ('TURNER J', 'LIAO YINGCHEN')
# Authors Pairs:  ('LIAO YINGCHEN', 'UNNIKRISHNAN D')
# Authors Pairs inv:  ('UNNIKRISHNAN D', 'LIAO YINGCHEN')
# Authors Pairs:  ('LIAO YINGCHEN', 'WANG Y')
# Authors Pairs inv:  ('WANG Y', 'LIAO YINGCHEN')
# Authors Pairs:  ('LIAO YINGCHEN', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'LIAO YINGCHEN')
# Authors Pairs:  ('LIAO YINGCHEN', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'LIAO YINGCHEN')
# Authors Pairs:  ('LU GH', 'PFAFF B.')
# Authors Pairs inv:  ('PFAFF B.', 'LU GH')
# Authors Pairs:  ('LU GH', 'RUIZ-SANCHEZ MA')
# Authors Pairs inv:  ('RUIZ-SANCHEZ MA', 'LU GH')
# Authors Pairs:  ('LU GH', 'SOLTESZ S.')
# Authors Pairs inv:  ('SOLTESZ S.', 'LU GH')
# Authors Pairs:  ('LU GH', 'SONG H.')
# Authors Pairs inv:  ('SONG H.', 'LU GH')
# Authors Pairs:  ('LU GH', 'TURNER J')
# Authors Pairs inv:  ('TURNER J', 'LU GH')
# Authors Pairs:  ('LU GH', 'UNNIKRISHNAN D')
# Authors Pairs inv:  ('UNNIKRISHNAN D', 'LU GH')
# Authors Pairs:  ('LU GH', 'WANG Y')
# Authors Pairs inv:  ('WANG Y', 'LU GH')
# Authors Pairs:  ('LU GH', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'LU GH')
# Authors Pairs:  ('LU GH', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'LU GH')
# Authors Pairs:  ('PFAFF B.', 'RUIZ-SANCHEZ MA')
# Authors Pairs inv:  ('RUIZ-SANCHEZ MA', 'PFAFF B.')
# Authors Pairs:  ('PFAFF B.', 'SOLTESZ S.')
# Authors Pairs inv:  ('SOLTESZ S.', 'PFAFF B.')
# Authors Pairs:  ('PFAFF B.', 'SONG H.')
# Authors Pairs inv:  ('SONG H.', 'PFAFF B.')
# Authors Pairs:  ('PFAFF B.', 'TURNER J')
# Authors Pairs inv:  ('TURNER J', 'PFAFF B.')
# Authors Pairs:
#  ('PFAFF B.', 'UNNIKRISHNAN D')
# Authors Pairs inv:  ('UNNIKRISHNAN D', 'PFAFF B.')
# Authors Pairs:  ('PFAFF B.', 'WANG Y')
# Authors Pairs inv:  ('WANG Y', 'PFAFF B.')
# Authors Pairs:  ('PFAFF B.', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'PFAFF B.')
# Authors Pairs:  ('PFAFF B.', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'PFAFF B.')
# Authors Pairs:  ('RUIZ-SANCHEZ MA', 'SOLTESZ S.')
# Authors Pairs inv:  ('SOLTESZ S.', 'RUIZ-SANCHEZ MA')
# Authors Pairs:  ('RUIZ-SANCHEZ MA', 'SONG H.')
# Authors Pairs inv:  ('SONG H.', 'RUIZ-SANCHEZ MA')
# Authors Pairs:  ('RUIZ-SANCHEZ MA', 'TURNER J')
# Authors Pairs inv:  ('TURNER J', 'RUIZ-SANCHEZ MA')
# Authors Pairs:  ('RUIZ-SANCHEZ MA', 'UNNIKRISHNAN D')
# Authors Pairs inv:  ('UNNIKRISHNAN D', 'RUIZ-SANCHEZ MA')
# Authors Pairs:  ('RUIZ-SANCHEZ MA', 'WANG Y')
# Authors Pairs inv:  ('WANG Y', 'RUIZ-SANCHEZ MA')
# Authors Pairs:  ('RUIZ-SANCHEZ MA', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'RUIZ-SANCHEZ MA')
# Authors Pairs:  ('RUIZ-SANCHEZ MA', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'RUIZ-SANCHEZ MA')
# Authors Pairs:  ('SOLTESZ S.', 'SONG H.')
# Authors Pairs inv:  ('SONG H.', 'SOLTESZ S.')
# Authors Pairs:  ('SOLTESZ S.', 'TURNER J')
# Authors Pairs inv:  ('TURNER J', 'SOLTESZ S.')
# Authors Pairs:  ('SOLTESZ S.', 'UNNIKRISHNAN D')
# Authors Pairs inv:  ('UNNIKRISHNAN D', 'SOLTESZ S.')
# Authors Pairs:  ('SOLTESZ S.', 'WANG Y')
# Authors Pairs inv:  ('WANG Y', 'SOLTESZ S.')
# Authors Pairs:  ('SOLTESZ S.', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'SOLTESZ S.')
# Authors Pairs:  ('SOLTESZ S.', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'SOLTESZ S.')
# Authors Pairs:  ('SONG H.', 'TURNER J')
# Authors Pairs inv:  ('TURNER J', 'SONG H.')
# Authors Pairs:  ('SONG H.', 'UNNIKRISHNAN D')
# Authors Pairs inv:  ('UNNIKRISHNAN D', 'SONG H.')
# Authors Pairs:  ('SONG H.', 'WANG Y')
# Authors Pairs inv:  ('WANG Y', 'SONG H.')
# Authors Pairs:  ('SONG H.', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'SONG H.')
# Authors Pairs:  ('SONG H.', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'SONG H.')
# Authors Pairs:  ('TURNER J', 'UNNIKRISHNAN D')
# Authors Pairs inv:  ('UNNIKRISHNAN D', 'TURNER J')
# Authors Pairs:  ('TURNER J', 'WANG Y')
# Authors Pairs inv:  ('WANG Y', 'TURNER J')
# Authors Pairs:  ('TURNER J', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'TURNER J')
# Authors Pairs:  ('TURNER J', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'TURNER J')
# Authors Pairs:  ('UNNIKRISHNAN D', 'WANG Y')
# Authors Pairs inv:  ('WANG Y', 'UNNIKRISHNAN D')
# Authors Pairs:  ('UNNIKRISHNAN D', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'UNNIKRISHNAN D')
# Authors Pairs:  ('UNNIKRISHNAN D', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'UNNIKRISHNAN D')
# Authors Pairs:  ('WANG Y', 'WATSON G.')
# Authors Pairs inv:  ('WATSON G.', 'WANG Y')
# Authors Pairs:  ('WANG Y', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'WANG Y')
# Authors Pairs:  ('WATSON G.', 'ZHUANG L.')
# Authors Pairs inv:  ('ZHUANG L.', 'WATSON G.')
# Authors Pairs:  ('ABBOTT TG', 'BAUER K')
# Authors Pairs inv:  ('BAUER K', 'ABBOTT TG')
# Authors Pairs:  ('ABBOTT TG', 'CHAUM DL')
# Authors Pairs inv:  ('CHAUM DL', 'ABBOTT TG')
# Authors Pairs:  ('ABBOTT TG', 'DANEZIS G')
# Authors Pairs inv:  ('DANEZIS G', 'ABBOTT TG')
# Authors Pairs:  ('ABBOTT TG', 'DINGLEDINE R')
# Authors Pairs inv:  ('DINGLEDINE R', 'ABBOTT TG')
# Authors Pairs:  ('ABBOTT TG', 'DINGLEDINE R')
# Authors Pairs inv:  ('DINGLEDINE R', 'ABBOTT TG')
# Authors Pairs:  ('ABBOTT TG', 'EVANS N.')
# Authors Pairs inv:  ('EVANS N.', 'ABBOTT TG')
# Authors Pairs:  ('ABBOTT TG', 'HOUMANSADR A')
# Authors Pairs inv:  ('HOUMANSADR A', 'ABBOTT TG')
# Authors Pairs:  ('ABBOTT TG', 'KARAGIANNIS T')
# Authors Pairs inv:  ('KARAGIANNIS T', 'ABBOTT TG')
# Authors Pairs:  ('ABBOTT TG', 'KOPSELL S')
# Authors Pairs inv:  ('KOPSELL S', 'ABBOTT TG')
# Authors Pairs:  ('ABBOTT TG', 'LARSEN M')
# Authors Pairs inv:  ('LARSEN M', 'ABBOTT TG')
# Authors Pairs:  ('ABBOTT TG', 'LEVINE BN')
# Authors Pairs inv:  ('LEVINE BN', 'ABBOTT TG')
# Authors Pairs:  ('ABBOTT TG', 'LING Z.')
# Authors Pairs inv:  ('LING Z.', 'ABBOTT TG')
# Authors Pairs:  ('ABBOTT TG', 'LING Z')
# Authors Pairs inv:  ('LING Z', 'ABBOTT TG')
# Authors Pairs:  ('ABBOTT TG', 'MANILS P')
# Authors Pairs inv:  ('MANILS P', 'ABBOTT TG')
# Authors Pairs:  ('ABBOTT TG', 'MCLACHLAN J')
# Authors Pairs inv:  ('MCLACHLAN J', 'ABBOTT TG')
# Authors Pairs:  ('ABBOTT TG', 'MURDOCH SJ')
# Authors Pairs inv:  ('MURDOCH SJ', 'ABBOTT TG')
# Authors Pairs:  ('ABBOTT TG', 'MURDOCH SJ')
# Authors Pairs inv:  ('MURDOCH SJ', 'ABBOTT TG')
# Authors Pairs:  ('ABBOTT TG', 'OVERLIER L')
# Authors Pairs inv:  ('OVERLIER L', 'ABBOTT TG')
# Authors Pairs:  ('ABBOTT TG', 'PRIES R')
# Authors Pairs inv:  ('PRIES R', 'ABBOTT TG')
# Authors Pairs:  ('ABBOTT TG', 'PYUN YJ')
# Authors Pairs inv:  ('PYUN YJ', 'ABBOTT TG')
# Authors Pairs:  ('ABBOTT TG', 'WANG X')
# Authors Pairs inv:  ('WANG X', 'ABBOTT TG')
# Authors Pairs:  ('ABBOTT TG', 'WANG X')
# Authors Pairs inv:  ('WANG X', 'ABBOTT TG')
# Authors Pairs:  ('ABBOTT TG', 'YU W')
# Authors Pairs inv:  ('YU W', 'ABBOTT TG')
# Authors Pairs:  ('ABBOTT TG', 'ZANDER S')
# Authors Pairs inv:  ('ZANDER S', 'ABBOTT TG')
# Authors Pairs:  ('ABBOTT TG', 'ZHU Y.')
# Authors Pairs inv:  ('ZHU Y.', 'ABBOTT TG')
# Authors Pairs:  ('BAUER K', 'CHAUM DL')
# Authors Pairs inv:  ('CHAUM DL', 'BAUER K')
# Authors Pairs:  ('BAUER K', 'DANEZIS G')
# Authors Pairs inv:  ('DANEZIS G', 'BAUER K')
# Authors Pairs:  ('BAUER K', 'DINGLEDINE R')
# Authors Pairs inv:  ('DINGLEDINE R', 'BAUER K')
# Authors Pairs:  ('BAUER K', 'DINGLEDINE R')
# Authors Pairs inv:  ('DINGLEDINE R', 'BAUER K')
# Authors Pairs:  ('BAUER K', 'EVANS N.')
# Authors Pairs inv:  ('EVANS N.', 'BAUER K')
# Authors Pairs:  ('BAUER K', 'HOUMANSADR A')
# Authors Pairs inv:  ('HOUMANSADR A', 'BAUER K')
# Authors Pairs:  ('BAUER K', 'KARAGIANNIS T')
# Authors Pairs inv:  ('KARAGIANNIS T', 'BAUER K')
# Authors Pairs:  ('BAUER K', 'KOPSELL S')
# Authors Pairs inv:  ('KOPSELL S', 'BAUER K')
# Authors Pairs:  ('BAUER K', 'LARSEN M')
# Authors Pairs inv:  ('LARSEN M', 'BAUER K')
# Authors Pairs:  ('BAUER K', 'LEVINE BN')
# Authors Pairs inv:  ('LEVINE BN', 'BAUER K')
# Authors Pairs:  ('BAUER K', 'LING Z.')
# Authors Pairs inv:  ('LING Z.', 'BAUER K')
# Authors Pairs:  ('BAUER K', 'LING Z')
# Authors Pairs inv:  ('LING Z', 'BAUER K')
# Authors Pairs:  ('BAUER K', 'MANILS P')
# Authors Pairs inv:  ('MANILS P', 'BAUER K')
# Authors Pairs:  ('BAUER K', 'MCLACHLAN J')
# Authors Pairs inv:  ('MCLACHLAN J', 'BAUER K')
# Authors Pairs:  ('BAUER K', 'MURDOCH SJ')
# Authors Pairs inv:  ('MURDOCH SJ', 'BAUER K')
# Authors Pairs:  ('BAUER K', 'MURDOCH SJ')
# Authors Pairs inv:  ('MURDOCH SJ', 'BAUER K')
# Authors Pairs:  ('BAUER K', 'OVERLIER L')
# Authors Pairs inv:  ('OVERLIER L', 'BAUER K')
# Authors Pairs:  ('BAUER K', 'PRIES R')
# Authors Pairs inv:  ('PRIES R', 'BAUER K')
# Authors Pairs:  ('BAUER K', 'PYUN YJ')
# Authors Pairs inv:  ('PYUN YJ', 'BAUER K')
# Authors Pairs:  ('BAUER K', 'WANG X')
# Authors Pairs inv:  ('WANG X', 'BAUER K')
# Authors Pairs:  ('BAUER K', 'WANG X')
# Authors Pairs inv:  ('WANG X', 'BAUER K')
# Authors Pairs:  ('BAUER K', 'YU W')
# Authors Pairs inv:  ('YU W', 'BAUER K')
# Authors Pairs:  ('BAUER K', 'ZANDER S')
# Authors Pairs inv:  ('ZANDER S', 'BAUER K')
# Authors Pairs:  ('BAUER K', 'ZHU Y.')
# Authors Pairs inv:  ('ZHU Y.', 'BAUER K')
# Authors Pairs:  ('CHAUM DL', 'DANEZIS G')
# Authors Pairs inv:  ('DANEZIS G', 'CHAUM DL')
# Authors Pairs:  ('CHAUM DL', 'DINGLEDINE R')
# Authors Pairs inv:  ('DINGLEDINE R', 'CHAUM DL')
# Authors Pairs:  ('CHAUM DL', 'DINGLEDINE R')
# Authors Pairs inv:  ('DINGLEDINE R', 'CHAUM DL')
# Authors Pairs:  ('CHAUM DL', 'EVANS N.')
# Authors Pairs inv:  ('EVANS N.', 'CHAUM DL')
# Authors Pairs:  ('CHAUM DL', 'HOUMANSADR A')
# Authors Pairs inv:  ('HOUMANSADR A', 'CHAUM DL')
# Authors Pairs:  ('CHAUM DL', 'KARAGIANNIS T')
# Authors Pairs inv:  ('KARAGIANNIS T', 'CHAUM DL')
# Authors Pairs:  ('CHAUM DL', 'KOPSELL S')
# Authors Pairs inv:  ('KOPSELL S', 'CHAUM DL')
# Authors Pairs:  ('CHAUM DL', 'LARSEN M')
# Authors Pairs inv:  ('LARSEN M', 'CHAUM DL')
# Authors Pairs:  ('CHAUM DL', 'LEVINE BN')
# Authors Pairs inv:  ('LEVINE BN', 'CHAUM DL')
# Authors Pairs:  ('CHAUM DL', 'LING Z.')
# Authors Pairs inv:  ('LING Z.', 'CHAUM DL')
# Authors Pairs:  ('CHAUM DL', 'LING Z')
# Authors Pairs inv:  ('LING Z', 'CHAUM DL')
# Authors Pairs:  ('CHAUM DL', 'MANILS P')
# Authors Pairs inv:  ('MANILS P', 'CHAUM DL')
# Authors Pairs:  ('CHAUM DL', 'MCLACHLAN J')
# Authors Pairs inv:  ('MCLACHLAN J', 'CHAUM DL')
# Authors Pairs:  ('CHAUM DL', 'MURDOCH SJ')
# Authors Pairs inv:  ('MURDOCH SJ', 'CHAUM DL')
# Authors Pairs:  ('CHAUM DL', 'MURDOCH SJ')
# Authors Pairs inv:  ('MURDOCH SJ', 'CHAUM DL')
# Authors Pairs:  ('CHAUM DL', 'OVERLIER L')
# Authors Pairs inv:  ('OVERLIER L', 'CHAUM DL')
# Authors Pairs:  ('CHAUM DL', 'PRIES R')
# Authors Pairs inv:  ('PRIES R', 'CHAUM DL')
# Authors Pairs:  ('CHAUM DL', 'PYUN YJ')
# Authors Pairs inv:  ('PYUN YJ', 'CHAUM DL')
# Authors Pairs:  ('CHAUM DL', 'WANG X')
# Authors Pairs inv:  ('WANG X', 'CHAUM DL')
# Authors Pairs:  ('CHAUM DL', 'WANG X')
# Authors Pairs inv:  ('WANG X', 'CHAUM DL')
# Authors Pairs:  ('CHAUM DL', 'YU W')
# Authors Pairs inv:  ('YU W', 'CHAUM DL')
# Authors Pairs:  ('CHAUM DL', 'ZANDER S')
# Authors Pairs inv:  ('ZANDER S', 'CHAUM DL')
# Authors Pairs:  ('CHAUM DL', 'ZHU Y.')
# Authors Pairs inv:  ('ZHU Y.', 'CHAUM DL')
# Authors Pairs:  ('DANEZIS G', 'DINGLEDINE R')
# Authors Pairs inv:  ('DINGLEDINE R', 'DANEZIS G')
# Authors Pairs:  ('DANEZIS G', 'DINGLEDINE R')
# Authors Pairs inv:  ('DINGLEDINE R', 'DANEZIS G')
# Authors Pairs:  ('DANEZIS G', 'EVANS N.')
# Authors Pairs inv:  ('EVANS N.', 'DANEZIS G')
# Authors Pairs:  ('DANEZIS G', 'HOUMANSADR A')
# Authors Pairs inv:  ('HOUMANSADR A', 'DANEZIS G')
# Authors Pairs:  ('DANEZIS G', 'KARAGIANNIS T')
# Authors Pairs inv:  ('KARAGIANNIS T', 'DANEZIS G')
# Authors Pairs:  ('DANEZIS G', 'KOPSELL S')
# Authors Pairs inv:  ('KOPSELL S', 'DANEZIS G')
# Authors Pairs:  ('DANEZIS G', 'LARSEN M')
# Authors Pairs inv:  ('LARSEN M', 'DANEZIS G')
# Authors Pairs:  ('DANEZIS G', 'LEVINE BN')
# Authors Pairs inv:  ('LEVINE BN', 'DANEZIS G')
# Authors Pairs:  ('DANEZIS G', 'LING Z.')
# Authors Pairs inv:  ('LING Z.', 'DANEZIS G')
# Authors Pairs:  ('DANEZIS G', 'LING Z')
# Authors Pairs inv:  ('LING Z', 'DANEZIS G')
# Authors Pairs:  ('DANEZIS G', 'MANILS P')
# Authors Pairs inv:  ('MANILS P', 'DANEZIS G')
# Authors Pairs:  ('DANEZIS G', 'MCLACHLAN J')
# Authors Pairs inv:  ('MCLACHLAN J', 'DANEZIS G')
# Authors Pairs:  ('DANEZIS G', 'MURDOCH SJ')
# Authors Pairs inv:  ('MURDOCH SJ', 'DANEZIS G')
# Authors Pairs:  ('DANEZIS G', 'MURDOCH SJ')
# Authors Pairs inv:  ('MURDOCH SJ', 'DANEZIS G')
# Authors Pairs:  ('DANEZIS G', 'OVERLIER L')
# Authors Pairs inv:  ('OVERLIER L', 'DANEZIS G')
# Authors Pairs:  ('DANEZIS G', 'PRIES R')
# Authors Pairs inv:  ('PRIES R', 'DANEZIS G')
# Authors Pairs:  ('DANEZIS G', 'PYUN YJ')
# Authors Pairs inv:  ('PYUN YJ', 'DANEZIS G')
# Authors Pairs:  ('DANEZIS G', 'WANG X')
# Authors Pairs inv:  ('WANG X', 'DANEZIS G')
# Authors Pairs:  ('DANEZIS G', 'WANG X')
# Authors Pairs inv:  ('WANG X', 'DANEZIS G')
# Authors Pairs:  ('DANEZIS G', 'YU W')
# Authors Pairs inv:  ('YU W', 'DANEZIS G')
# Authors Pairs:  ('DANEZIS G', 'ZANDER S')
# Authors Pairs inv:  ('ZANDER S', 'DANEZIS G')
# Authors Pairs:  ('DANEZIS G', 'ZHU Y.')
# Authors Pairs inv:  ('ZHU Y.', 'DANEZIS G')
# Authors Pairs:  ('DINGLEDINE R', 'DINGLEDINE R')
# Authors Pairs inv:  ('DINGLEDINE R', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'EVANS N.')
# Authors Pairs inv:  ('EVANS N.', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'HOUMANSADR A')
# Authors Pairs inv:  ('HOUMANSADR A', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'KARAGIANNIS T')
# Authors Pairs inv:  ('KARAGIANNIS T', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'KOPSELL S')
# Authors Pairs inv:  ('KOPSELL S', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'LARSEN M')
# Authors Pairs inv:  ('LARSEN M', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'LEVINE BN')
# Authors Pairs inv:  ('LEVINE BN', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'LING Z.')
# Authors Pairs inv:  ('LING Z.', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'LING Z')
# Authors Pairs inv:  ('LING Z', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'MANILS P')
# Authors Pairs inv:  ('MANILS P', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'MCLACHLAN J')
# Authors Pairs inv:  ('MCLACHLAN J', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'MURDOCH SJ')
# Authors Pairs inv:  ('MURDOCH SJ', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'MURDOCH SJ')
# Authors Pairs inv:  ('MURDOCH SJ', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'OVERLIER L')
# Authors Pairs inv:  ('OVERLIER L', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'PRIES R')
# Authors Pairs inv:  ('PRIES R', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'PYUN YJ')
# Authors Pairs inv:  ('PYUN YJ', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'WANG X')
# Authors Pairs inv:  ('WANG X', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'WANG X')
# Authors Pairs inv:  ('WANG X', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'YU W')
# Authors Pairs inv:  ('YU W', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'ZANDER S')
# Authors Pairs inv:  ('ZANDER S', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'ZHU Y.')
# Authors Pairs inv:  ('ZHU Y.', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'EVANS N.')
# Authors Pairs inv:  ('EVANS N.', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'HOUMANSADR A')
# Authors Pairs inv:  ('HOUMANSADR A', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'KARAGIANNIS T')
# Authors Pairs inv:  ('KARAGIANNIS T', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'KOPSELL S')
# Authors Pairs inv:  ('KOPSELL S', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'LARSEN M')
# Authors Pairs inv:  ('LARSEN M', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'LEVINE BN')
# Authors Pairs inv:  ('LEVINE BN', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'LING Z.')
# Authors Pairs inv:  ('LING Z.', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'LING Z')
# Authors Pairs inv:  ('LING Z', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'MANILS P')
# Authors Pairs inv:  ('MANILS P', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'MCLACHLAN J')
# Authors Pairs inv:  ('MCLACHLAN J', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'MURDOCH SJ')
# Authors Pairs inv:  ('MURDOCH SJ', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'MURDOCH SJ')
# Authors Pairs inv:  ('MURDOCH SJ', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'OVERLIER L')
# Authors Pairs inv:  ('OVERLIER L', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'PRIES R')
# Authors Pairs inv:  ('PRIES R', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'PYUN YJ')
# Authors Pairs inv:  ('PYUN YJ', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'WANG X')
# Authors Pairs inv:  ('WANG X', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'WANG X')
# Authors Pairs inv:  ('WANG X', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'YU W')
# Authors Pairs inv:  ('YU W', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'ZANDER S')
# Authors Pairs inv:  ('ZANDER S', 'DINGLEDINE R')
# Authors Pairs:  ('DINGLEDINE R', 'ZHU Y.')
# Authors Pairs inv:  ('ZHU Y.', 'DINGLEDINE R')
# Authors Pairs:  ('EVANS N.', 'HOUMANSADR A')
# Authors Pairs inv:  ('HOUMANSADR A', 'EVANS N.')
# Authors Pairs:  ('EVANS N.', 'KARAGIANNIS T')
# Authors Pairs inv:  ('KARAGIANNIS T', 'EVANS N.')
# Authors Pairs:  ('EVANS N.', 'KOPSELL S')
# Authors Pairs inv:  ('KOPSELL S', 'EVANS N.')
# Authors Pairs:  ('EVANS N.', 'LARSEN M')
# Authors Pairs inv:  ('LARSEN M', 'EVANS N.')
# Authors Pairs:  ('EVANS N.', 'LEVINE BN')
# Authors Pairs inv:  ('LEVINE BN', 'EVANS N.')
# Authors Pairs:  ('EVANS N.', 'LING Z.')
# Authors Pairs inv:  ('LING Z.', 'EVANS N.')
# Authors Pairs:  ('EVANS N.', 'LING Z')
# Authors Pairs inv:  ('LING Z', 'EVANS N.')
# Authors Pairs:  ('EVANS N.', 'MANILS P')
# Authors Pairs inv:  ('MANILS P', 'EVANS N.')
# Authors Pairs:  ('EVANS N.', 'MCLACHLAN J')
# Authors Pairs inv:  ('MCLACHLAN J', 'EVANS N.')
# Authors Pairs:  ('EVANS N.', 'MURDOCH SJ')
# Authors Pairs inv:  ('MURDOCH SJ', 'EVANS N.')
# Authors Pairs:  ('EVANS N.', 'MURDOCH SJ')
# Authors Pairs inv:  ('MURDOCH SJ', 'EVANS N.')
# Authors Pairs:  ('EVANS N.', 'OVERLIER L')
# Authors Pairs inv:  ('OVERLIER L', 'EVANS N.')
# Authors Pairs:  ('EVANS N.', 'PRIES R')
# Authors Pairs inv:  ('PRIES R', 'EVANS N.')
# Authors Pairs:  ('EVANS N.', 'PYUN YJ')
# Authors Pairs inv:  ('PYUN YJ', 'EVANS N.')
# Authors Pairs:  ('EVANS N.', 'WANG X')
# Authors Pairs inv:  ('WANG X', 'EVANS N.')
# Authors Pairs:  ('EVANS N.', 'WANG X')
# Authors Pairs inv:  ('WANG X', 'EVANS N.')
# Authors Pairs:  ('EVANS N.', 'YU W')
# Authors Pairs inv:  ('YU W', 'EVANS N.')
# Authors Pairs:  ('EVANS N.', 'ZANDER S')
# Authors Pairs inv:  ('ZANDER S', 'EVANS N.')
# Authors Pairs:  ('EVANS N.', 'ZHU Y.')
# Authors Pairs inv:  ('ZHU Y.', 'EVANS N.')
# ...
# Authors Pairs inv:  ('SHELBY Z.', 'PALATTELLA MR')
# Authors Pairs:  ('PALATTELLA MR', 'SHELBY Z.')
# Authors Pairs inv:  ('SHELBY Z.', 'PALATTELLA MR')
# Authors Pairs:  ('PALATTELLA MR', 'SIVAGAMI A')
# Authors Pairs inv:  ('SIVAGAMI A', 'PALATTELLA MR')
# Authors Pairs:  ('PALATTELLA MR', 'VETTER RJ')
# Authors Pairs inv:  ('VETTER RJ', 'PALATTELLA MR')
# Authors Pairs:  ('PALATTELLA MR', 'WATTEYNE T')
# Authors Pairs inv:  ('WATTEYNE T', 'PALATTELLA MR')
# Authors Pairs:
#  ('PALATTELLA MR', 'WATTEYNE T')
# Authors Pairs inv:  ('WATTEYNE T', 'PALATTELLA MR')
# Authors Pairs:  ('PALATTELLA MR', 'WINTER T.')
# Authors Pairs inv:  ('WINTER T.', 'PALATTELLA MR')
# Authors Pairs:  ('PALATTELLA MR', 'ZHANG L')
# Authors Pairs inv:  ('ZHANG L', 'PALATTELLA MR')
# Authors Pairs:  ('PALATTELLA MR', 'ZHOU G.')
# Authors Pairs inv:  ('ZHOU G.', 'PALATTELLA MR')
# Authors Pairs:  ('PARK KJ', 'POSTEL J.')
# Authors Pairs inv:  ('POSTEL J.', 'PARK KJ')
# Authors Pairs:  ('PARK KJ', 'POSTEL J')
# Authors Pairs inv:  ('POSTEL J', 'PARK KJ')
# Authors Pairs:  ('PARK KJ', 'ROSEN E.')
# Authors Pairs inv:  ('ROSEN E.', 'PARK KJ')
# Authors Pairs:  ('PARK KJ', 'SCAGLIONE A')
# Authors Pairs inv:  ('SCAGLIONE A', 'PARK KJ')
# Authors Pairs:  ('PARK KJ', 'SHELBY Z.')
# Authors Pairs inv:  ('SHELBY Z.', 'PARK KJ')
# Authors Pairs:  ('PARK KJ', 'SHELBY Z.')
# Authors Pairs inv:  ('SHELBY Z.', 'PARK KJ')
# Authors Pairs:  ('PARK KJ', 'SIVAGAMI A')
# Authors Pairs inv:  ('SIVAGAMI A', 'PARK KJ')
# Authors Pairs:  ('PARK KJ', 'VETTER RJ')
# Authors Pairs inv:  ('VETTER RJ', 'PARK KJ')
# Authors Pairs:  ('PARK KJ', 'WATTEYNE T')
# Authors Pairs inv:  ('WATTEYNE T', 'PARK KJ')
# Authors Pairs:  ('PARK KJ', 'WATTEYNE T')
# Authors Pairs inv:  ('WATTEYNE T', 'PARK KJ')
# Authors Pairs:  ('PARK KJ', 'WINTER T.')
# Authors Pairs inv:  ('WINTER T.', 'PARK KJ')
# Authors Pairs:  ('PARK KJ', 'ZHANG L')
# Authors Pairs inv:  ('ZHANG L', 'PARK KJ')
# Authors Pairs:  ('PARK KJ', 'ZHOU G.')
# Authors Pairs inv:  ('ZHOU G.', 'PARK KJ')
# Authors Pairs:  ('POSTEL J.', 'POSTEL J')
# Authors Pairs inv:  ('POSTEL J', 'POSTEL J.')
# Authors Pairs:  ('POSTEL J.', 'ROSEN E.')
# Authors Pairs inv:  ('ROSEN E.', 'POSTEL J.')
# Authors Pairs:  ('POSTEL J.', 'SCAGLIONE A')
# Authors Pairs inv:  ('SCAGLIONE A', 'POSTEL J.')
# Authors Pairs:  ('POSTEL J.', 'SHELBY Z.')
# Authors Pairs inv:  ('SHELBY Z.', 'POSTEL J.')
# Authors Pairs:  ('POSTEL J.', 'SHELBY Z.')
# Authors Pairs inv:  ('SHELBY Z.', 'POSTEL J.')
# Authors Pairs:  ('POSTEL J.', 'SIVAGAMI A')
# Authors Pairs inv:  ('SIVAGAMI A', 'POSTEL J.')
# Authors Pairs:  ('POSTEL J.', 'VETTER RJ')
# Authors Pairs inv:  ('VETTER RJ', 'POSTEL J.')
# Authors Pairs:  ('POSTEL J.', 'WATTEYNE T')
# Authors Pairs inv:  ('WATTEYNE T', 'POSTEL J.')
# Authors Pairs:  ('POSTEL J.', 'WATTEYNE T')
# Authors Pairs inv:  ('WATTEYNE T', 'POSTEL J.')
# Authors Pairs:  ('POSTEL J.', 'WINTER T.')
# Authors Pairs inv:  ('WINTER T.', 'POSTEL J.')
# Authors Pairs:  ('POSTEL J.', 'ZHANG L')
# Authors Pairs inv:  ('ZHANG L', 'POSTEL J.')
# Authors Pairs:  ('POSTEL J.', 'ZHOU G.')
# Authors Pairs inv:  ('ZHOU G.', 'POSTEL J.')
# Authors Pairs:  ('POSTEL J', 'ROSEN E.')
# Authors Pairs inv:  ('ROSEN E.', 'POSTEL J')
# Authors Pairs:  ('POSTEL J', 'SCAGLIONE A')
# Authors Pairs inv:  ('SCAGLIONE A', 'POSTEL J')
# Authors Pairs:  ('POSTEL J', 'SHELBY Z.')
# Authors Pairs inv:  ('SHELBY Z.', 'POSTEL J')
# Authors Pairs:  ('POSTEL J', 'SHELBY Z.')
# Authors Pairs inv:  ('SHELBY Z.', 'POSTEL J')
# Authors Pairs:  ('POSTEL J', 'SIVAGAMI A')
# Authors Pairs inv:  ('SIVAGAMI A', 'POSTEL J')
# Authors Pairs:  ('POSTEL J', 'VETTER RJ')
# Authors Pairs inv:  ('VETTER RJ', 'POSTEL J')
# Authors Pairs:  ('POSTEL J', 'WATTEYNE T')
# Authors Pairs inv:  ('WATTEYNE T', 'POSTEL J')
# Authors Pairs:  ('POSTEL J', 'WATTEYNE T')
# Authors Pairs inv:  ('WATTEYNE T', 'POSTEL J')
# Authors Pairs:  ('POSTEL J', 'WINTER T.')
# Authors Pairs inv:  ('WINTER T.', 'POSTEL J')
# Authors Pairs:  ('POSTEL J', 'ZHANG L')
# Authors Pairs inv:  ('ZHANG L', 'POSTEL J')
# Authors Pairs:  ('POSTEL J', 'ZHOU G.')
# Authors Pairs inv:  ('ZHOU G.', 'POSTEL J')
# Authors Pairs:  ('ROSEN E.', 'SCAGLIONE A')
# Authors Pairs inv:  ('SCAGLIONE A', 'ROSEN E.')
# Authors Pairs:  ('ROSEN E.', 'SHELBY Z.')
# Authors Pairs inv:  ('SHELBY Z.', 'ROSEN E.')
# Authors Pairs:  ('ROSEN E.', 'SHELBY Z.')
# Authors Pairs inv:  ('SHELBY Z.', 'ROSEN E.')
# Authors Pairs:  ('ROSEN E.', 'SIVAGAMI A')
# Authors Pairs inv:  ('SIVAGAMI A', 'ROSEN E.')
# Authors Pairs:  ('ROSEN E.', 'VETTER RJ')
# Authors Pairs inv:  ('VETTER RJ', 'ROSEN E.')
# Authors Pairs:  ('ROSEN E.', 'WATTEYNE T')
# Authors Pairs inv:  ('WATTEYNE T', 'ROSEN E.')
# Authors Pairs:  ('ROSEN E.', 'WATTEYNE T')
# Authors Pairs inv:  ('WATTEYNE T', 'ROSEN E.')
# Authors Pairs:  ('ROSEN E.', 'WINTER T.')
# Authors Pairs inv:  ('WINTER T.', 'ROSEN E.')
# Authors Pairs:  ('ROSEN E.', 'ZHANG L')
# Authors Pairs inv:  ('ZHANG L', 'ROSEN E.')
# Authors Pairs:  ('ROSEN E.', 'ZHOU G.')
# Authors Pairs inv:  ('ZHOU G.', 'ROSEN E.')
# Authors Pairs:  ('SCAGLIONE A', 'SHELBY Z.')
# Authors Pairs inv:  ('SHELBY Z.', 'SCAGLIONE A')
# Authors Pairs:  ('SCAGLIONE A', 'SHELBY Z.')
# Authors Pairs inv:  ('SHELBY Z.', 'SCAGLIONE A')
# Authors Pairs:  ('SCAGLIONE A', 'SIVAGAMI A')
# Authors Pairs inv:  ('SIVAGAMI A', 'SCAGLIONE A')
# Authors Pairs:  ('SCAGLIONE A', 'VETTER RJ')
# Authors Pairs inv:  ('VETTER RJ', 'SCAGLIONE A')
# Authors Pairs:  ('SCAGLIONE A', 'WATTEYNE T')
# Authors Pairs inv:  ('WATTEYNE T', 'SCAGLIONE A')
# Authors Pairs:  ('SCAGLIONE A', 'WATTEYNE T')
# Authors Pairs inv:  ('WATTEYNE T', 'SCAGLIONE A')
# Authors Pairs:  ('SCAGLIONE A', 'WINTER T.')
# Authors Pairs inv:  ('WINTER T.', 'SCAGLIONE A')
# Authors Pairs:  ('SCAGLIONE A', 'ZHANG L')
# Authors Pairs inv:  ('ZHANG L', 'SCAGLIONE A')
# Authors Pairs:  ('SCAGLIONE A', 'ZHOU G.')
# Authors Pairs inv:  ('ZHOU G.', 'SCAGLIONE A')
# Authors Pairs:  ('SHELBY Z.', 'SHELBY Z.')
# Authors Pairs inv:  ('SHELBY Z.', 'SHELBY Z.')
# Authors Pairs:  ('SHELBY Z.', 'SIVAGAMI A')
# Authors Pairs inv:  ('SIVAGAMI A', 'SHELBY Z.')
# Authors Pairs:  ('SHELBY Z.', 'VETTER RJ')
# Authors Pairs inv:  ('VETTER RJ', 'SHELBY Z.')
# Authors Pairs:  ('SHELBY Z.', 'WATTEYNE T')
# Authors Pairs inv:  ('WATTEYNE T', 'SHELBY Z.')
# Authors Pairs:  ('SHELBY Z.', 'WATTEYNE T')
# Authors Pairs inv:  ('WATTEYNE T', 'SHELBY Z.')
# Authors Pairs:  ('SHELBY Z.', 'WINTER T.')
# Authors Pairs inv:  ('WINTER T.', 'SHELBY Z.')
# Authors Pairs:  ('SHELBY Z.', 'ZHANG L')
# Authors Pairs inv:  ('ZHANG L', 'SHELBY Z.')
# Authors Pairs:  ('SHELBY Z.', 'ZHOU G.')
# Authors Pairs inv:  ('ZHOU G.', 'SHELBY Z.')
# Authors Pairs:  ('SHELBY Z.', 'SIVAGAMI A')
# Authors Pairs inv:  ('SIVAGAMI A', 'SHELBY Z.')
# Authors Pairs:  ('SHELBY Z.', 'VETTER RJ')
# Authors Pairs inv:  ('VETTER RJ', 'SHELBY Z.')
# Authors Pairs:  ('SHELBY Z.', 'WATTEYNE T')
# Authors Pairs inv:  ('WATTEYNE T', 'SHELBY Z.')
# Authors Pairs:  ('SHELBY Z.', 'WATTEYNE T')
# Authors Pairs inv:  ('WATTEYNE T', 'SHELBY Z.')
# Authors Pairs:  ('SHELBY Z.', 'WINTER T.')
# Authors Pairs inv:  ('WINTER T.', 'SHELBY Z.')
# Authors Pairs:  ('SHELBY Z.', 'ZHANG L')
# Authors Pairs inv:  ('ZHANG L', 'SHELBY Z.')
# Authors Pairs:  ('SHELBY Z.', 'ZHOU G.')
# Authors Pairs inv:  ('ZHOU G.', 'SHELBY Z.')
# Authors Pairs:  ('SIVAGAMI A', 'VETTER RJ')
# Authors Pairs inv:  ('VETTER RJ', 'SIVAGAMI A')
# Authors Pairs:  ('SIVAGAMI A', 'WATTEYNE T')
# Authors Pairs inv:  ('WATTEYNE T', 'SIVAGAMI A')
# Authors Pairs:  ('SIVAGAMI A', 'WATTEYNE T')
# Authors Pairs inv:  ('WATTEYNE T', 'SIVAGAMI A')
# Authors Pairs:  ('SIVAGAMI A', 'WINTER T.')
# Authors Pairs inv:  ('WINTER T.', 'SIVAGAMI A')
# Authors Pairs:  ('SIVAGAMI A', 'ZHANG L')
# Authors Pairs inv:  ('ZHANG L', 'SIVAGAMI A')
# Authors Pairs:  ('SIVAGAMI A', 'ZHOU G.')
# Authors Pairs inv:  ('ZHOU G.', 'SIVAGAMI A')
# Authors Pairs:  ('VETTER RJ', 'WATTEYNE T')
# Authors Pairs inv:  ('WATTEYNE T', 'VETTER RJ')
# Authors Pairs:  ('VETTER RJ', 'WATTEYNE T')
# Authors Pairs inv:  ('WATTEYNE T', 'VETTER RJ')
# Authors Pairs:  ('VETTER RJ', 'WINTER T.')
# Authors Pairs inv:  ('WINTER T.', 'VETTER RJ')
# Authors Pairs:  ('VETTER RJ', 'ZHANG L')
# Authors Pairs inv:  ('ZHANG L', 'VETTER RJ')
# Authors Pairs:  ('VETTER RJ', 'ZHOU G.')
# Authors Pairs inv:  ('ZHOU G.', 'VETTER RJ')
# Authors Pairs:  ('WATTEYNE T', 'WATTEYNE T')
# Authors Pairs inv:  ('WATTEYNE T', 'WATTEYNE T')
# Authors Pairs:  ('WATTEYNE T', 'WINTER T.')
# Authors Pairs inv:  ('WINTER T.', 'WATTEYNE T')
# Authors Pairs:  ('WATTEYNE T', 'ZHANG L')
# Authors Pairs inv:  ('ZHANG L', 'WATTEYNE T')
# Authors Pairs:  ('WATTEYNE T', 'ZHOU G.')
# Authors Pairs inv:  ('ZHOU G.', 'WATTEYNE T')
# Authors Pairs:  ('WATTEYNE T', 'WINTER T.')
# Authors Pairs inv:  ('WINTER T.', 'WATTEYNE T')
# Authors Pairs:  ('WATTEYNE T', 'ZHANG L')
# Authors Pairs inv:  ('ZHANG L', 'WATTEYNE T')
# Authors Pairs:  ('WATTEYNE T', 'ZHOU G.')
# Authors Pairs inv:  ('ZHOU G.', 'WATTEYNE T')
# Authors Pairs:  ('WINTER T.', 'ZHANG L')
# Authors Pairs inv:  ('ZHANG L', 'WINTER T.')
# Authors Pairs:  ('WINTER T.', 'ZHOU G.')
# Authors Pairs inv:  ('ZHOU G.', 'WINTER T.')
# Authors Pairs:  ('ZHANG L', 'ZHOU G.')
# Authors Pairs inv:  ('ZHOU G.', 'ZHANG L')
# Authors Pairs:  ('AL-SURMI I', 'CHIANG KH')
# Authors Pairs inv:  ('CHIANG KH', 'AL-SURMI I')
# Authors Pairs:  ('AL-SURMI I', 'GUNDAVELLI S.')
# Authors Pairs inv:  ('GUNDAVELLI S.', 'AL-SURMI I')
# Authors Pairs:  ('AL-SURMI I', 'JOHNSON D.')
# Authors Pairs inv:  ('JOHNSON D.', 'AL-SURMI I')
# Authors Pairs:  ('AL-SURMI I', 'KEMPF J.')
# Authors Pairs inv:  ('KEMPF J.', 'AL-SURMI I')
# Authors Pairs:  ('AL-SURMI I', 'KEMPF J.')
# Authors Pairs inv:  ('KEMPF J.', 'AL-SURMI I')
# Authors Pairs:  ('AL-SURMI I', 'KONG KS')
# Authors Pairs inv:  ('KONG KS', 'AL-SURMI I')
# Authors Pairs:  ('AL-SURMI I', 'KOODLI R.')
# Authors Pairs inv:  ('KOODLI R.', 'AL-SURMI I')
# Authors Pairs:  ('AL-SURMI I', 'LEE KW')
# Authors Pairs inv:  ('LEE KW', 'AL-SURMI I')
# Authors Pairs:  ('AL-SURMI I', 'NEUMANN N.')
# Authors Pairs inv:  ('NEUMANN N.', 'AL-SURMI I')
# Authors Pairs:  ('AL-SURMI I', 'NEUMANN N.')
# Authors Pairs inv:  ('NEUMANN N.', 'AL-SURMI I')
# Authors Pairs:  ('AL-SURMI I', 'SOLIMAN H.')
# Authors Pairs inv:  ('SOLIMAN H.', 'AL-SURMI I')
# Authors Pairs:  ('AL-SURMI I', 'ZHONG F')
# Authors Pairs inv:  ('ZHONG F', 'AL-SURMI I')
# Authors Pairs:  ('CHIANG KH', 'GUNDAVELLI S.')
# Authors Pairs inv:  ('GUNDAVELLI S.', 'CHIANG KH')
# Authors Pairs:  ('CHIANG KH', 'JOHNSON D.')
# Authors Pairs inv:  ('JOHNSON D.', 'CHIANG KH')
# Authors Pairs:  ('CHIANG KH', 'KEMPF J.')
# Authors Pairs inv:  ('KEMPF J.', 'CHIANG KH')
# Authors Pairs:  ('CHIANG KH', 'KEMPF J.')
# Authors Pairs inv:  ('KEMPF J.', 'CHIANG KH')
# Authors Pairs:  ('CHIANG KH', 'KONG KS')
# Authors Pairs inv:  ('KONG KS', 'CHIANG KH')
# Authors Pairs:  ('CHIANG KH', 'KOODLI R.')
# Authors Pairs inv:  ('KOODLI R.', 'CHIANG KH')
# Authors Pairs:  ('CHIANG KH', 'LEE KW')
# Authors Pairs inv:  ('LEE KW', 'CHIANG KH')
# Authors Pairs:  ('CHIANG KH', 'NEUMANN N.')
# Authors Pairs inv:  ('NEUMANN N.', 'CHIANG KH')
# Authors Pairs:  ('CHIANG KH', 'NEUMANN N.')
# Authors Pairs inv:  ('NEUMANN N.', 'CHIANG KH')
# Authors Pairs:  ('CHIANG KH', 'SOLIMAN H.')
# Authors Pairs inv:  ('SOLIMAN H.', 'CHIANG KH')
# Authors Pairs:  ('CHIANG KH', 'ZHONG F')
# Authors Pairs inv:  ('ZHONG F', 'CHIANG KH')
# Authors Pairs:  ('GUNDAVELLI S.', 'JOHNSON D.')
# Authors Pairs inv:  ('JOHNSON D.', 'GUNDAVELLI S.')
# Authors Pairs:  ('GUNDAVELLI S.', 'KEMPF J.')
# Authors Pairs inv:  ('KEMPF J.', 'GUNDAVELLI S.')
# Authors Pairs:  ('GUNDAVELLI S.', 'KEMPF J.')
# Authors Pairs inv:  ('KEMPF J.', 'GUNDAVELLI S.')
# Authors Pairs:  ('GUNDAVELLI S.', 'KONG KS')
# Authors Pairs inv:  ('KONG KS', 'GUNDAVELLI S.')
# Authors Pairs:  ('GUNDAVELLI S.', 'KOODLI R.')
# Authors Pairs inv:  ('KOODLI R.', 'GUNDAVELLI S.')
# Authors Pairs:  ('GUNDAVELLI S.', 'LEE KW')
# Authors Pairs inv:  ('LEE KW', 'GUNDAVELLI S.')
# Authors Pairs:  ('GUNDAVELLI S.', 'NEUMANN N.')
# Authors Pairs inv:  ('NEUMANN N.', 'GUNDAVELLI S.')
# Authors Pairs:  ('GUNDAVELLI S.', 'NEUMANN N.')
# Authors Pairs inv:  ('NEUMANN N.', 'GUNDAVELLI S.')
# Authors Pairs:  ('GUNDAVELLI S.', 'SOLIMAN H.')
# Authors Pairs inv:  ('SOLIMAN H.', 'GUNDAVELLI S.')
# Authors Pairs:  ('GUNDAVELLI S.', 'ZHONG F')
# Authors Pairs inv:  ('ZHONG F', 'GUNDAVELLI S.')
# Authors Pairs:  ('JOHNSON D.', 'KEMPF J.')
# Authors Pairs inv:  ('KEMPF J.', 'JOHNSON D.')
# Authors Pairs:  ('JOHNSON D.', 'KEMPF J.')
# Authors Pairs inv:  ('KEMPF J.', 'JOHNSON D.')
# Authors Pairs:  ('JOHNSON D.', 'KONG KS')
# Authors Pairs inv:  ('KONG KS', 'JOHNSON D.')
# Authors Pairs:  ('JOHNSON D.', 'KOODLI R.')
# Authors Pairs inv:  ('KOODLI R.', 'JOHNSON D.')
# Authors Pairs:  ('JOHNSON D.', 'LEE KW')
# Authors Pairs inv:  ('LEE KW', 'JOHNSON D.')
# Authors Pairs:  ('JOHNSON D.', 'NEUMANN N.')
# Authors Pairs inv:  ('NEUMANN N.', 'JOHNSON D.')
# Authors Pairs:  ('JOHNSON D.', 'NEUMANN N.')
# Authors Pairs inv:  ('NEUMANN N.', 'JOHNSON D.')
# Authors Pairs:  ('JOHNSON D.', 'SOLIMAN H.')
# Authors Pairs inv:  ('SOLIMAN H.', 'JOHNSON D.')
# Authors Pairs:  ('JOHNSON D.', 'ZHONG F')
# Authors Pairs inv:  ('ZHONG F', 'JOHNSON D.')
# Authors Pairs:  ('KEMPF J.', 'KEMPF J.')
# Authors Pairs inv:  ('KEMPF J.', 'KEMPF J.')
# Authors Pairs:  ('KEMPF J.', 'KONG KS')
# Authors Pairs inv:  ('KONG KS', 'KEMPF J.')
# Authors Pairs:  ('KEMPF J.', 'KOODLI R.')
# Authors Pairs inv:  ('KOODLI R.', 'KEMPF J.')
# Authors Pairs:  ('KEMPF J.', 'LEE KW')
# Authors Pairs inv:  ('LEE KW', 'KEMPF J.')
# Authors Pairs:  ('KEMPF J.', 'NEUMANN N.')
# Authors Pairs inv:  ('NEUMANN N.', 'KEMPF J.')
# Authors Pairs:  ('KEMPF J.', 'NEUMANN N.')
# Authors Pairs inv:  ('NEUMANN N.', 'KEMPF J.')
# Authors Pairs:  ('KEMPF J.', 'SOLIMAN H.')
# Authors Pairs inv:  ('SOLIMAN H.', 'KEMPF J.')
# Authors Pairs:  ('KEMPF J.', 'ZHONG F')
# Authors Pairs inv:  ('ZHONG F', 'KEMPF J.')
# Authors Pairs:  ('KEMPF J.', 'KONG KS')
# Authors Pairs inv:  ('KONG KS', 'KEMPF J.')
# Authors Pairs:  ('KEMPF J.', 'KOODLI R.')
# Authors Pairs inv:  ('KOODLI R.', 'KEMPF J.')
# Authors Pairs:  ('KEMPF J.', 'LEE KW')
# Authors Pairs inv:  ('LEE KW', 'KEMPF J.')
# Authors Pairs:  ('KEMPF J.', 'NEUMANN N.')
# Authors Pairs inv:  ('NEUMANN N.', 'KEMPF J.')
# Authors Pairs:  ('KEMPF J.', 'NEUMANN N.')
# Authors Pairs inv:  ('NEUMANN N.', 'KEMPF J.')
# Authors Pairs:  ('KEMPF J.', 'SOLIMAN H.')
# Authors Pairs inv:  ('SOLIMAN H.', 'KEMPF J.')
# Authors Pairs:  ('KEMPF J.', 'ZHONG F')
# Authors Pairs inv:  ('ZHONG F', 'KEMPF J.')
# Authors Pairs:  ('KONG KS', 'KOODLI R.')
# Authors Pairs inv:  ('KOODLI R.', 'KONG KS')
# Authors Pairs:  ('KONG KS', 'LEE KW')
# Authors Pairs inv:  ('LEE KW', 'KONG KS')
# Authors Pairs:  ('KONG KS', 'NEUMANN N.')
# Authors Pairs inv:  ('NEUMANN N.', 'KONG KS')
# Authors Pairs:  ('KONG KS', 'NEUMANN N.')
# Authors Pairs inv:  ('NEUMANN N.', 'KONG KS')
# Authors Pairs:  ('KONG KS', 'SOLIMAN H.')
# Authors Pairs inv:  ('SOLIMAN H.', 'KONG KS')
# Authors Pairs:  ('KONG KS', 'ZHONG F')
# Authors Pairs inv:  ('ZHONG F', 'KONG KS')
# Authors Pairs:  ('KOODLI R.', 'LEE KW')
# Authors Pairs inv:  ('LEE KW', 'KOODLI R.')
# Authors Pairs:  ('KOODLI R.', 'NEUMANN N.')
# Authors Pairs inv:  ('NEUMANN N.', 'KOODLI R.')
# Authors Pairs:  ('KOODLI R.', 'NEUMANN N.')
# Authors Pairs inv:  ('NEUMANN N.', 'KOODLI R.')
# Authors Pairs:  ('KOODLI R.', 'SOLIMAN H.')
# Authors Pairs inv:  ('SOLIMAN H.', 'KOODLI R.')
# Authors Pairs:  ('KOODLI R.', 'ZHONG F')
# Authors Pairs inv:  ('ZHONG F', 'KOODLI R.')
# Authors Pairs:  ('LEE KW', 'NEUMANN N.')
# Authors Pairs inv:  ('NEUMANN N.', 'LEE KW')
# Authors Pairs:  ('LEE KW', 'NEUMANN N.')
# Authors Pairs inv:  ('NEUMANN N.', 'LEE KW')
# Authors Pairs:  ('LEE KW', 'SOLIMAN H.')
# Authors Pairs inv:  ('SOLIMAN H.', 'LEE KW')
# Authors Pairs:  ('LEE KW', 'ZHONG F')
# Authors Pairs inv:  ('ZHONG F', 'LEE KW')
# Authors Pairs:  ('NEUMANN N.', 'NEUMANN N.')
# Authors Pairs inv:  ('NEUMANN N.', 'NEUMANN N.')
# Authors Pairs:  ('NEUMANN N.', 'SOLIMAN H.')
# Authors Pairs inv:  ('SOLIMAN H.', 'NEUMANN N.')
# Authors Pairs:  ('NEUMANN N.', 'ZHONG F')
# Authors Pairs inv:  ('ZHONG F', 'NEUMANN N.')
# Authors Pairs:  ('NEUMANN N.', 'SOLIMAN H.')
# Authors Pairs inv:  ('SOLIMAN H.', 'NEUMANN N.')
# Authors Pairs:  ('NEUMANN N.', 'ZHONG F')
# Authors Pairs inv:  ('ZHONG F', 'NEUMANN N.')
# Authors Pairs:  ('SOLIMAN H.', 'ZHONG F')
# Authors Pairs inv:  ('ZHONG F', 'SOLIMAN H.')

# %%
aList = ['123', 'xyz', 'zara', 'abc'];
bList = ['223', 'sssz', 'zaara', 'abc'];

L = ['L','O','L']
makeitastringdammit = ''.join(map(str, L))
print type(makeitastringdammit)

new= aList+bList
print new

cList=[]
delim=' ' 
for i in xrange(len(aList)):
    cList.append(aList[i] + delim + bList[i]);
    print "Updated List : ", cList;
# Out:
# <type 'str'>
# ['123', 'xyz', 'zara', 'abc', '223', 'sssz', 'zaara', 'abc']
# Updated List :  ['123 223']
# Updated List :  ['123 223', 'xyz sssz']
# Updated List :  ['123 223', 'xyz sssz', 'zara zaara']
# Updated List :  ['123 223', 'xyz sssz', 'zara zaara', 'abc abc']

# %%
ref="Anonymous, 2013, UND FULL VIRT PAR HA"
tokens= ref.split(' ')
print tokens
name= tokens[0]
print name
name=l.split(' ')
print name
print 'else' ,name[0],name[1]
print len(name)
if(name):
    print 'hi'
else:
    print 'else'
# Out:
# ['Anonymous,', '2013,', 'UND', 'FULL', 'VIRT', 'PAR', 'HA']
# Anonymous,
# ['[Anonymous],', '2013,', 'UND', 'FULL', 'VIRT', 'PAR', 'HA']
# else [Anonymous], 2013,
# 7
# hi

# %%
list_of_ints = [80, 443, 8080, 8081]
ss=str(list_of_ints).strip('[ ]')
print ss,type(ss)
# Out:
# 80, 443, 8080, 8081 <type 'str'>

# %%
import tethne.readers as rd
filepath = "../testsuite/testin/cocitations_test_full.txt"
wos_list = rd.wos.parse_wos(filepath)

meta_list=rd.wos.wos2meta(wos_list)

for paper in meta_list:
    for citation in paper['citations']:
        #aug_list= citation['aulast'],' ',  citation['auinit']
        #print paper['citations'][i]['aulast']
        #print aug_list,len(aug_list)
        #print citation['date'],len(citation['auinit'])
        pass
import tethne.networks as nt
author_cocitations = nt.authors.author_cocitation(meta_list, 2)
#print author_cocitations.nodes()
print author_cocitations.edges()
# Out:
# ----New paper---
# no of citations: 60
# main name --- i: ['Adriano']
# first name: ['Adriano']
# except except : ADRIANO D. ADRIANO 'D.'
# first name: ['Alloway']
# except except : ADRIANO D. ALLOWAY 'B.'
# first name: ['Bogaert']
# except except : ADRIANO D. BOGAERT 'P.'
# first name: ['Brown']
# except except : ADRIANO D. BROWN 'K.'
# first name: ['Christakos']
# except except : ADRIANO D. CHRISTAKOS 'G.'
# first name: ['Christakos']
# except except : ADRIANO D. CHRISTAKOS 'G'
# first name: ['Christakos']
# try: ADRIANO D. CHRISTAKOS 'G.'
# first name: ['Clark']
# except except : ADRIANO D. CLARK 'L.'
# first name: ['Crnkovic']
# except except : ADRIANO D. CRNKOVIC 'D'
# first name: ['Dang']
# except except : ADRIANO D. DANG 'Z'
# first name: ['Dawes']
# except except : ADRIANO D. DAWES 'A'
# first name: ['Dimitrakopoulos']
# except except : ADRIANO D. DIMITRAKOPOULOS 'D.'
# first name: ['DUDAS']
# except except : ADRIANO D. DUDAS 'MJ'
# first name: ['Harmeling']
# except except : ADRIANO D. HARMELING 'S'
# first name: ['Hodge']
# except except : ADRIANO D. HODGE 'VJ'
# first name: ['Hotelling']
# except except : ADRIANO D. HOTELLING 'H.'
# first name: ['Juszczak']
# except except : ADRIANO D. JUSZCZAK 'P'
# first name: ['Kang']
# except except : ADRIANO D. KANG 'P'
# first name: ['Kang']
# try: ADRIANO D. KANG 'P'
# first name: ['Environmental']
# except except : ADRIANO D. ENVIRONMENTAL 'PROTECTION'
# first name: ['FAO']
# except except : ADRIANO D. FAO ''
# first name: ['FILIPPIDIS']
# except except : ADRIANO D. FILIPPIDIS 'A'
# first name: ['Finkelman']
# except except : ADRIANO D. FINKELMAN 'R.B.'
# first name: ['Georgakopoulos']
# except except : ADRIANO D. GEORGAKOPOULOS 'A.'
# first name: ['Gerouki']
# except except : ADRIANO D. GEROUKI 'F.'
# first name: ['HART']
# except except : ADRIANO D. HART 'JD'
# first name: ['Hartley']
# except except : ADRIANO D. HARTLEY 'W'
# first name: ['Hristopoulos']
# except except : ADRIANO D. HRISTOPOULOS 'D.'
# first name: ['ICRCL']
# except except : ADRIANO D. ICRCL NONE
# first name: ['James']
# except except : ADRIANO D. JAMES 'BR'
# first name: ['Journel']
# except except : ADRIANO D. JOURNEL 'A.G.'
# first name: ['Kabata-Pendias']
# except except : ADRIANO D. KABATA-PENDIAS 'A.'
# first name: ['Kavouridis']
# except except : ADRIANO D. KAVOURIDIS 'K'
# first name: ['Kolovos']
# except except : ADRIANO D. KOLOVOS 'N'
# first name: ['Komnitsas']
# except except : ADRIANO D. KOMNITSAS 'K'
# first name: ['Komnitsas']
# try: ADRIANO D. KOMNITSAS 'K'
# first name: ['Modis']
# except except : ADRIANO D. MODIS 'K'
# first name: ['Modis']
# except except : ADRIANO D. MODIS 'K.'
# first name: ['Nielsen']
# except except : ADRIANO D. NIELSEN 'F.'
# first name: ['Orem']
# except except : ADRIANO D. OREM 'W.'
# first name: ['PAVLIDES']
# except except : ADRIANO D. PAVLIDES 'SB'
# first name: ['Pentari']
# except except : ADRIANO D. PENTARI 'D'
# first name: ['Petrotou']
# except except : ADRIANO D. PETROTOU 'A.'
# first name: ['Pills']
# except except : ADRIANO D. PILLS 'J.'
# first name: ['Rose']
# except except : ADRIANO D. ROSE 'A.'
# first name: ['Sadiq']
# except except : ADRIANO D. SADIQ 'M'
# first name: ['Serre']
# except except : ADRIANO D. SERRE 'ML'
# first name: ['Snakin']
# except except : ADRIANO D. SNAKIN 'VV'
# first name: ['Swaine']
# except except : ADRIANO D. SWAINE 'D.'
# first name: ['Swaine']
# try: ADRIANO D. SWAINE 'D.'
# first name: ['Swaine']
# except except : ADRIANO D. SWAINE 'DJ'
# first name: ['Sylaios']
# except except : ADRIANO D. SYLAIOS 'G'
# first name: ['Tang']
# except except : ADRIANO D. TANG 'JC'
# first name: ['Triantafyllou']
# except except : ADRIANO D. TRIANTAFYLLOU 'AG'
# first name: ['Vatalis']
# except except : ADRIANO D. VATALIS 'K.'
# first name: ['Vatalis']
# except except : ADRIANO D. VATALIS 'KI'
# first name: ['Vatalis']
# try: ADRIANO D. VATALIS 'KI'
# first name: ['Xiao']
# except except : ADRIANO D. XIAO 'HY'
# first name: ['Yu']
# except except : ADRIANO D. YU 'HL'
# main name --- i: ['Adriano']
# first name: ['Alloway']
# try: ADRIANO D. ALLOWAY 'B.'
# first name: ['Bogaert']
# try: ADRIANO D. BOGAERT 'P.'
# first name: ['Brown']
# try: ADRIANO D. BROWN 'K.'
# first name: ['Christakos']
# try: ADRIANO D. CHRISTAKOS 'G.'
# first name: ['Christakos']
# try: ADRIANO D. CHRISTAKOS 'G'
# first name: ['Christakos']
# try: ADRIANO D. CHRISTAKOS 'G.'
# first name: ['Clark']
# try: ADRIANO D. CLARK 'L.'
# first name: ['Crnkovic']
# try: ADRIANO D. CRNKOVIC 'D'
# first name: ['Dang']
# try: ADRIANO D. DANG 'Z'
# first name: ['Dawes']
# try: ADRIANO D. DAWES 'A'
# first name: ['Dimitrakopoulos']
# try: ADRIANO D. DIMITRAKOPOULOS 'D.'
# first name: ['DUDAS']
# try: ADRIANO D. DUDAS 'MJ'
# first name: ['Harmeling']
# try: ADRIANO D. HARMELING 'S'
# first name: ['Hodge']
# try: ADRIANO D. HODGE 'VJ'
# first name: ['Hotelling']
# try: ADRIANO D. HOTELLING 'H.'
# first name: ['Juszczak']
# try: ADRIANO D. JUSZCZAK 'P'
# first name: ['Kang']
# try: ADRIANO D. KANG 'P'
# first name: ['Kang']
# try: ADRIANO D. KANG 'P'
# first name: ['Environmental']
# try: ADRIANO D. ENVIRONMENTAL 'PROTECTION'
# first name: ['FAO']
# try: ADRIANO D. FAO ''
# first name: ['FILIPPIDIS']
# try: ADRIANO D. FILIPPIDIS 'A'
# first name: ['Finkelman']
# try: ADRIANO D. FINKELMAN 'R.B.'
# first name: ['Georgakopoulos']
# try: ADRIANO D. GEORGAKOPOULOS 'A.'
# first name: ['Gerouki']
# try: ADRIANO D. GEROUKI 'F.'
# first name: ['HART']
# try: ADRIANO D. HART 'JD'
# first name: ['Hartley']
# try: ADRIANO D. HARTLEY 'W'
# first name: ['Hristopoulos']
# try: ADRIANO D. HRISTOPOULOS 'D.'
# first name: ['ICRCL']
# try: ADRIANO D. ICRCL NONE
# first name: ['James']
# try: ADRIANO D. JAMES 'BR'
# first name: ['Journel']
# try: ADRIANO D. JOURNEL 'A.G.'
# first name: ['Kabata-Pendias']
# try: ADRIANO D. KABATA-PENDIAS 'A.'
# first name: ['Kavouridis']
# try: ADRIANO D. KAVOURIDIS 'K'
# first name: ['Kolovos']
# try: ADRIANO D. KOLOVOS 'N'
# first name: ['Komnitsas']
# try: ADRIANO D. KOMNITSAS 'K'
# first name: ['Komnitsas']
# try: ADRIANO D. KOMNITSAS 'K'
# first name: ['Modis']
# try: ADRIANO D. MODIS 'K'
# first name: ['Modis']
# try: ADRIANO D. MODIS 'K.'
# first name: ['Nielsen']
# try: ADRIANO D. NIELSEN 'F.'
# first name: ['Orem']
# try: ADRIANO D. OREM 'W.'
# first name: ['PAVLIDES']
# try: ADRIANO D. PAVLIDES 'SB'
# first name: ['Pentari']
# try: ADRIANO D. PENTARI 'D'
# first name: ['Petrotou']
# try: ADRIANO D. PETROTOU 'A.'
# first name: ['Pills']
# try: ADRIANO D. PILLS 'J.'
# first name: ['Rose']
# try: ADRIANO D. ROSE 'A.'
# first name: ['Sadiq']
# try: ADRIANO D. SADIQ 'M'
# first name: ['Serre']
# try: ADRIANO D. SERRE 'ML'
# first name: ['Snakin']
# try: ADRIANO D. SNAKIN 'VV'
# first name: ['Swaine']
# try: ADRIANO D. SWAINE 'D.'
# first name: ['Swaine']
# try: ADRIANO D. SWAINE 'D.'
# first name: ['Swaine']
# try: ADRIANO D. SWAINE 'DJ'
# first name: ['Sylaios']
# try: ADRIANO D. SYLAIOS 'G'
# first name: ['Tang']
# try: ADRIANO D. TANG 'JC'
# first name: ['Triantafyllou']
# try: ADRIANO D. TRIANTAFYLLOU 'AG'
# first name: ['Vatalis']
# try: ADRIANO D. VATALIS 'K.'
# first name: ['Vatalis']
# try: ADRIANO D. VATALIS 'KI'
# first name: ['Vatalis']
# try: ADRIANO D. VATALIS 'KI'
# first name: ['Xiao']
# try: ADRIANO D. XIAO 'HY'
# first name: ['Yu']
# try: ADRIANO D. YU 'HL'
# main name --- i: ['Alloway']
# first name: ['Bogaert']
# except except : ALLOWAY B. BOGAERT 'P.'
# first name: ['Brown']
# except except : ALLOWAY B. BROWN 'K.'
# first name: ['Christakos']
# except except : ALLOWAY B. CHRISTAKOS 'G.'
# first name: ['Christakos']
# except except : ALLOWAY B. CHRISTAKOS 'G'
# first name: ['Christakos']
# try: ALLOWAY B. CHRISTAKOS 'G.'
# first name: ['Clark']
# except except : ALLOWAY B. CLARK 'L.'
# first name: ['Crnkovic']
# except except : ALLOWAY B. CRNKOVIC 'D'
# first name: ['Dang']
# except except : ALLOWAY B. DANG 'Z'
# first name: ['Dawes']
# except except : ALLOWAY B. DAWES 'A'
# first name: ['Dimitrakopoulos']
# except except : ALLOWAY B. DIMITRAKOPOULOS 'D.'
# first name: ['DUDAS']
# except except : ALLOWAY B. DUDAS 'MJ'
# first name: ['Harmeling']
# except except : ALLOWAY B. HARMELING 'S'
# first name: ['Hodge']
# except except : ALLOWAY B. HODGE 'VJ'
# first name: ['Hotelling']
# except except : ALLOWAY B. HOTELLING 'H.'
# first name: ['Juszczak']
# except except : ALLOWAY B. JUSZCZAK 'P'
# first name: ['Kang']
# except except : ALLOWAY B. KANG 'P'
# first name: ['Kang']
# try: ALLOWAY B. KANG 'P'
# first name: ['Environmental']
# except except : ALLOWAY B. ENVIRONMENTAL 'PROTECTION'
# first name: ['FAO']
# except except : ALLOWAY B. FAO ''
# first name: ['FILIPPIDIS']
# except except : ALLOWAY B. FILIPPIDIS 'A'
# first name: ['Finkelman']
# except except : ALLOWAY B. FINKELMAN 'R.B.'
# first name: ['Georgakopoulos']
# except except : ALLOWAY B. GEORGAKOPOULOS 'A.'
# first name: ['Gerouki']
# except except : ALLOWAY B. GEROUKI 'F.'
# first name: ['HART']
# except except : ALLOWAY B. HART 'JD'
# first name: ['Hartley']
# except except : ALLOWAY B. HARTLEY 'W'
# first name: ['Hristopoulos']
# except except : ALLOWAY B. HRISTOPOULOS 'D.'
# first name: ['ICRCL']
# except except : ALLOWAY B. ICRCL NONE
# first name: ['James']
# except except : ALLOWAY B. JAMES 'BR'
# first name: ['Journel']
# except except : ALLOWAY B. JOURNEL 'A.G.'
# first name: ['Kabata-Pendias']
# except except : ALLOWAY B. KABATA-PENDIAS 'A.'
# first name: ['Kavouridis']
# except except : ALLOWAY B. KAVOURIDIS 'K'
# first name: ['Kolovos']
# except except : ALLOWAY B. KOLOVOS 'N'
# first name: ['Komnitsas']
# except except : ALLOWAY B. KOMNITSAS 'K'
# first name: ['Komnitsas']
# try: ALLOWAY B. KOMNITSAS 'K'
# first name: ['Modis']
# except except : ALLOWAY B. MODIS 'K'
# first name: ['Modis']
# except except : ALLOWAY B. MODIS 'K.'
# first name: ['Nielsen']
# except except : ALLOWAY B. NIELSEN 'F.'
# first name: ['Orem']
# except except : ALLOWAY B. OREM 'W.'
# first name: ['PAVLIDES']
# except except : ALLOWAY B. PAVLIDES 'SB'
# first name: ['Pentari']
# except except : ALLOWAY B. PENTARI 'D'
# first name: ['Petrotou']
# except except : ALLOWAY B. PETROTOU 'A.'
# first name: ['Pills']
# except except : ALLOWAY B. PILLS 'J.'
# first name: ['Rose']
# except except : ALLOWAY B. ROSE 'A.'
# first name: ['Sadiq']
# except except : ALLOWAY B. SADIQ 'M'
# first name: ['Serre']
# except except : ALLOWAY B. SERRE 'ML'
# first name: ['Snakin']
# except except : ALLOWAY B. SNAKIN 'VV'
# first name: ['Swaine']
# except except : ALLOWAY B. SWAINE 'D.'
# first name: ['Swaine']
# try: ALLOWAY B. SWAINE 'D.'
# first name: ['Swaine']
# except except : ALLOWAY B. SWAINE 'DJ'
# first name: ['Sylaios']
# except except : ALLOWAY B. SYLAIOS 'G'
# first name: ['Tang']
# except except : ALLOWAY B. TANG 'JC'
# first name: ['Triantafyllou']
# except except : ALLOWAY B. TRIANTAFYLLOU 'AG'
# first name: ['Vatalis']
# except except : ALLOWAY B. VATALIS 'K.'
# first name: ['Vatalis']
# except except : ALLOWAY B. VATALIS 'KI'
# first name: ['Vatalis']
# try: ALLOWAY B. VATALIS 'KI'
# first name: ['Xiao']
# except except : ALLOWAY B. XIAO 'HY'
# first name: ['Yu']
# except except : ALLOWAY B. YU 'HL'
# main name --- i: ['Bogaert']
# first name: ['Brown']
# except except : BOGAERT P. BROWN 'K.'
# first name: ['Christakos']
# except except : BOGAERT P. CHRISTAKOS 'G.'
# first name: ['Christakos']
# except except : BOGAERT P. CHRISTAKOS 'G'
# first name: ['Christakos']
# try: BOGAERT P. CHRISTAKOS 'G.'
# first name: ['Clark']
# except except : BOGAERT P. CLARK 'L.'
# first name: ['Crnkovic']
# except except : BOGAERT P. CRNKOVIC 'D'
# first name: ['Dang']
# except except : BOGAERT P. DANG 'Z'
# first name: ['Dawes']
# except except : BOGAERT P. DAWES 'A'
# first name: ['Dimitrakopoulos']
# except except : BOGAERT P. DIMITRAKOPOULOS 'D.'
# first name: ['DUDAS']
# except except : BOGAERT P. DUDAS 'MJ'
# first name: ['Harmeling']
# except except : BOGAERT P. HARMELING 'S'
# first name: ['Hodge']
# except except : BOGAERT P. HODGE 'VJ'
# first name: ['Hotelling']
# except except : BOGAERT P. HOTELLING 'H.'
# first name: ['Juszczak']
# except except : BOGAERT P. JUSZCZAK 'P'
# first name: ['Kang']
# except except : BOGAERT P. KANG 'P'
# first name: ['Kang']
# try: BOGAERT P. KANG 'P'
# first name: ['Environmental']
# except except : BOGAERT P. ENVIRONMENTAL 'PROTECTION'
# first name: ['FAO']
# except except : BOGAERT P. FAO ''
# first name: ['FILIPPIDIS']
# except except : BOGAERT P. FILIPPIDIS 'A'
# first name: ['Finkelman']
# except except : BOGAERT P. FINKELMAN 'R.B.'
# first name: ['Georgakopoulos']
# except except : BOGAERT P. GEORGAKOPOULOS 'A.'
# first name: ['Gerouki']
# except except : BOGAERT P. GEROUKI 'F.'
# first name: ['HART']
# except except : BOGAERT P. HART 'JD'
# first name: ['Hartley']
# except except : BOGAERT P. HARTLEY 'W'
# first name: ['Hristopoulos']
# except except : BOGAERT P. HRISTOPOULOS 'D.'
# first name: ['ICRCL']
# except except : BOGAERT P. ICRCL NONE
# first name: ['James']
# except except : BOGAERT P. JAMES 'BR'
# first name: ['Journel']
# except except : BOGAERT P. JOURNEL 'A.G.'
# first name: ['Kabata-Pendias']
# except except : BOGAERT P. KABATA-PENDIAS 'A.'
# first name: ['Kavouridis']
# except except : BOGAERT P. KAVOURIDIS 'K'
# first name: ['Kolovos']
# except except : BOGAERT P. KOLOVOS 'N'
# first name: ['Komnitsas']
# except except : BOGAERT P. KOMNITSAS 'K'
# first name: ['Komnitsas']
# try: BOGAERT P. KOMNITSAS 'K'
# first name: ['Modis']
# except except : BOGAERT P. MODIS 'K'
# first name: ['Modis']
# except except : BOGAERT P. MODIS 'K.'
# first name: ['Nielsen']
# except except : BOGAERT P. NIELSEN 'F.'
# first name: ['Orem']
# except except : BOGAERT P. OREM 'W.'
# first name: ['PAVLIDES']
# except except : BOGAERT P. PAVLIDES 'SB'
# first name: ['Pentari']
# except except : BOGAERT P. PENTARI 'D'
# first name: ['Petrotou']
# except except : BOGAERT P. PETROTOU 'A.'
# first name: ['Pills']
# except except : BOGAERT P. PILLS 'J.'
# first name: ['Rose']
# except except : BOGAERT P. ROSE 'A.'
# first name: ['Sadiq']
# except except : BOGAERT P. SADIQ 'M'
# first name: ['Serre']
# except except : BOGAERT P. SERRE 'ML'
# first name: ['Snakin']
# except except : BOGAERT P. SNAKIN 'VV'
# first name: ['Swaine']
# except except : BOGAERT P. SWAINE 'D.'
# first name: ['Swaine']
# try: BOGAERT P. SWAINE 'D.'
# first name: ['Swaine']
# except except : BOGAERT P. SWAINE 'DJ'
# first name: ['Sylaios']
# except except : BOGAERT P. SYLAIOS 'G'
# first name: ['Tang']
# except except : BOGAERT P. TANG 'JC'
# first name: ['Triantafyllou']
# except except : BOGAERT P. TRIANTAFYLLOU 'AG'
# first name: ['Vatalis']
# except except : BOGAERT P. VATALIS 'K.'
# first name: ['Vatalis']
# except except : BOGAERT P. VATALIS 'KI'
# first name: ['Vatalis']
# try: BOGAERT P. VATALIS 'KI'
# first name: ['Xiao']
# except except : BOGAERT P. XIAO 'HY'
# first name: ['Yu']
# except except : BOGAERT P. YU 'HL'
# main name --- i: ['Brown']
# first name: ['Christakos']
# except except : BROWN K. CHRISTAKOS 'G.'
# first name: ['Christakos']
# except except : BROWN K. CHRISTAKOS 'G'
# first name: ['Christakos']
# try: BROWN K. CHRISTAKOS 'G.'
# first name: ['Clark']
# except except : BROWN K. CLARK 'L.'
# first name: ['Crnkovic']
# except except : BROWN K. CRNKOVIC 'D'
# first name: ['Dang']
# except except : BROWN K. DANG 'Z'
# first name: ['Dawes']
# except except : BROWN K. DAWES 'A'
# first name: ['Dimitrakopoulos']
# except except : BROWN K. DIMITRAKOPOULOS 'D.'
# first name: ['DUDAS']
# except except : BROWN K. DUDAS 'MJ'
# first name: ['Harmeling']
# except except : BROWN K. HARMELING 'S'
# first name: ['Hodge']
# except except : BROWN K. HODGE 'VJ'
# first name: ['Hotelling']
# except except : BROWN K. HOTELLING 'H.'
# first name: ['Juszczak']
# except except : BROWN K. JUSZCZAK 'P'
# first name: ['Kang']
# except except : BROWN K. KANG 'P'
# first name: ['Kang']
# try: BROWN K. KANG 'P'
# first name: ['Environmental']
# except except : BROWN K. ENVIRONMENTAL 'PROTECTION'
# first name: ['FAO']
# except except : BROWN K. FAO ''
# first name: ['FILIPPIDIS']
# except except : BROWN K. FILIPPIDIS 'A'
# first name: ['Finkelman']
# except except : BROWN K. FINKELMAN 'R.B.'
# first name: ['Georgakopoulos']
# except except : BROWN K. GEORGAKOPOULOS 'A.'
# first name: ['Gerouki']
# except except : BROWN K. GEROUKI 'F.'
# first name: ['HART']
# except except : BROWN K. HART 'JD'
# first name: ['Hartley']
# except except : BROWN K. HARTLEY 'W'
# first name: ['Hristopoulos']
# except except : BROWN K. HRISTOPOULOS 'D.'
# first name: ['ICRCL']
# except except : BROWN K. ICRCL NONE
# first name: ['James']
# except except : BROWN K. JAMES 'BR'
# first name: ['Journel']
# except except : BROWN K. JOURNEL 'A.G.'
# first name: ['Kabata-Pendias']
# except except : BROWN K. KABATA-PENDIAS 'A.'
# first name: ['Kavouridis']
# except except : BROWN K. KAVOURIDIS 'K'
# first name: ['Kolovos']
# except except : BROWN K. KOLOVOS 'N'
# first name: ['Komnitsas']
# except except : BROWN K. KOMNITSAS 'K'
# first name: ['Komnitsas']
# try: BROWN K. KOMNITSAS 'K'
# first name: ['Modis']
# except except : BROWN K. MODIS 'K'
# first name: ['Modis']
# except except : BROWN K. MODIS 'K.'
# first name: ['Nielsen']
# except except : BROWN K. NIELSEN 'F.'
# first name: ['Orem']
# except except : BROWN K. OREM 'W.'
# first name: ['PAVLIDES']
# except except : BROWN K. PAVLIDES 'SB'
# first name: ['Pentari']
# except except : BROWN K. PENTARI 'D'
# first name: ['Petrotou']
# except except : BROWN K. PETROTOU 'A.'
# first name: ['Pills']
# except except : BROWN K. PILLS 'J.'
# first name: ['Rose']
# except except : BROWN K. ROSE 'A.'
# first name: ['Sadiq']
# except except : BROWN K. SADIQ 'M'
# first name: ['Serre']
# except except : BROWN K. SERRE 'ML'
# first name: ['Snakin']
# except except : BROWN K. SNAKIN 'VV'
# first name: ['Swaine']
# except except : BROWN K. SWAINE 'D.'
# first name: ['Swaine']
# try: BROWN K. SWAINE 'D.'
# first name: ['Swaine']
# except except : BROWN K. SWAINE 'DJ'
# first name: ['Sylaios']
# except except : BROWN K. SYLAIOS 'G'
# first name: ['Tang']
# except except : BROWN K. TANG 'JC'
# first name: ['Triantafyllou']
# except except : BROWN K. TRIANTAFYLLOU 'AG'
# first name: ['Vatalis']
# except except : BROWN K. VATALIS 'K.'
# first name: ['Vatalis']
# except except : BROWN K. VATALIS 'KI'
# first name: ['Vatalis']
# try: BROWN K. VATALIS 'KI'
# first name: ['Xiao']
# except except : BROWN K. XIAO 'HY'
# first name: ['Yu']
# except except : BROWN K. YU 'HL'
# main name --- i: ['Christakos']
# first name: ['Christakos']
# except except : CHRISTAKOS G. CHRISTAKOS 'G'
# first name: ['Christakos']
# except except : CHRISTAKOS G. CHRISTAKOS 'G.'
# first name: ['Clark']
# except except : CHRISTAKOS G. CLARK 'L.'
# first name: ['Crnkovic']
# except except : CHRISTAKOS G. CRNKOVIC 'D'
# first name: ['Dang']
# except except : CHRISTAKOS G. DANG 'Z'
# first name: ['Dawes']
# except except : CHRISTAKOS G. DAWES 'A'
# first name: ['Dimitrakopoulos']
# except except : CHRISTAKOS G. DIMITRAKOPOULOS 'D.'
# first name: ['DUDAS']
# except except : CHRISTAKOS G. DUDAS 'MJ'
# first name: ['Harmeling']
# except except : CHRISTAKOS G. HARMELING 'S'
# first name: ['Hodge']
# except except : CHRISTAKOS G. HODGE 'VJ'
# first name: ['Hotelling']
# except except : CHRISTAKOS G. HOTELLING 'H.'
# first name: ['Juszczak']
# except except : CHRISTAKOS G. JUSZCZAK 'P'
# first name: ['Kang']
# except except : CHRISTAKOS G. KANG 'P'
# first name: ['Kang']
# try: CHRISTAKOS G. KANG 'P'
# first name: ['Environmental']
# except except : CHRISTAKOS G. ENVIRONMENTAL 'PROTECTION'
# first name: ['FAO']
# except except : CHRISTAKOS G. FAO ''
# first name: ['FILIPPIDIS']
# except except : CHRISTAKOS G. FILIPPIDIS 'A'
# first name: ['Finkelman']
# except except : CHRISTAKOS G. FINKELMAN 'R.B.'
# first name: ['Georgakopoulos']
# except except : CHRISTAKOS G. GEORGAKOPOULOS 'A.'
# first name: ['Gerouki']
# except except : CHRISTAKOS G. GEROUKI 'F.'
# first name: ['HART']
# except except : CHRISTAKOS G. HART 'JD'
# first name: ['Hartley']
# except except : CHRISTAKOS G. HARTLEY 'W'
# first name: ['Hristopoulos']
# except except : CHRISTAKOS G. HRISTOPOULOS 'D.'
# first name: ['ICRCL']
# except except : CHRISTAKOS G. ICRCL NONE
# first name: ['James']
# except except : CHRISTAKOS G. JAMES 'BR'
# first name: ['Journel']
# except except : CHRISTAKOS G. JOURNEL 'A.G.'
# first name: ['Kabata-Pendias']
# except except : CHRISTAKOS G. KABATA-PENDIAS 'A.'
# first name: ['Kavouridis']
# except except : CHRISTAKOS G. KAVOURIDIS 'K'
# first name: ['Kolovos']
# except except : CHRISTAKOS G. KOLOVOS 'N'
# first name: ['Komnitsas']
# except except : CHRISTAKOS G. KOMNITSAS 'K'
# first name: ['Komnitsas']
# try: CHRISTAKOS G. KOMNITSAS 'K'
# first name: ['Modis']
# except except : CHRISTAKOS G. MODIS 'K'
# first name: ['Modis']
# except except : CHRISTAKOS G. MODIS 'K.'
# first name: ['Nielsen']
# except except : CHRISTAKOS G. NIELSEN 'F.'
# first name: ['Orem']
# except except : CHRISTAKOS G. OREM 'W.'
# first name: ['PAVLIDES']
# except except : CHRISTAKOS G. PAVLIDES 'SB'
# first name: ['Pentari']
# except except : CHRISTAKOS G. PENTARI 'D'
# first name: ['Petrotou']
# except except : CHRISTAKOS G. PETROTOU 'A.'
# first name: ['Pills']
# except except : CHRISTAKOS G. PILLS 'J.'
# first name: ['Rose']
# except except : CHRISTAKOS G. ROSE 'A.'
# first name: ['Sadiq']
# except except : CHRISTAKOS G. SADIQ 'M'
# first name: ['Serre']
# except except : CHRISTAKOS G. SERRE 'ML'
# first name: ['Snakin']
# except except : CHRISTAKOS G. SNAKIN 'VV'
# first name: ['Swaine']
# except except : CHRISTAKOS G. SWAINE 'D.'
# first name: ['Swaine']
# try: CHRISTAKOS G. SWAINE 'D.'
# first name: ['Swaine']
# except except : CHRISTAKOS G. SWAINE 'DJ'
# first name: ['Sylaios']
# except except : CHRISTAKOS G. SYLAIOS 'G'
# first name: ['Tang']
# except except : CHRISTAKOS G. TANG 'JC'
# first name: ['Triantafyllou']
# except except : CHRISTAKOS G. TRIANTAFYLLOU 'AG'
# first name: ['Vatalis']
# except except : CHRISTAKOS G. VATALIS 'K.'
# first name: ['Vatalis']
# except except : CHRISTAKOS G. VATALIS 'KI'
# first name: ['Vatalis']
# try: CHRISTAKOS G. VATALIS 'KI'
# first name: ['Xiao']
# except except : CHRISTAKOS G. XIAO 'HY'
# first name: ['Yu']
# except except : CHRISTAKOS G. YU 'HL'
# main name --- i: ['Christakos']
# first name: ['Christakos']
# except except : CHRISTAKOS G CHRISTAKOS 'G.'
# first name: ['Clark']
# except except : CHRISTAKOS G CLARK 'L.'
# first name: ['Crnkovic']
# except except : CHRISTAKOS G CRNKOVIC 'D'
# first name: ['Dang']
# except except : CHRISTAKOS G DANG 'Z'
# first name: ['Dawes']
# except except : CHRISTAKOS G DAWES 'A'
# first name: ['Dimitrakopoulos']
# except except : CHRISTAKOS G DIMITRAKOPOULOS 'D.'
# first name: ['DUDAS']
# except except : CHRISTAKOS G DUDAS 'MJ'
# first name: ['Harmeling']
# except except : CHRISTAKOS G HARMELING 'S'
# first name: ['Hodge']
# except except : CHRISTAKOS G HODGE 'VJ'
# first name: ['Hotelling']
# except except : CHRISTAKOS G HOTELLING 'H.'
# first name: ['Juszczak']
# except except : CHRISTAKOS G JUSZCZAK 'P'
# first name: ['Kang']
# except except : CHRISTAKOS G KANG 'P'
# first name: ['Kang']
# try: CHRISTAKOS G KANG 'P'
# first name: ['Environmental']
# except except : CHRISTAKOS G ENVIRONMENTAL 'PROTECTION'
# first name: ['FAO']
# except except : CHRISTAKOS G FAO ''
# first name: ['FILIPPIDIS']
# except except : CHRISTAKOS G FILIPPIDIS 'A'
# first name: ['Finkelman']
# except except : CHRISTAKOS G FINKELMAN 'R.B.'
# first name: ['Georgakopoulos']
# except except : CHRISTAKOS G GEORGAKOPOULOS 'A.'
# first name: ['Gerouki']
# except except : CHRISTAKOS G GEROUKI 'F.'
# first name: ['HART']
# except except : CHRISTAKOS G HART 'JD'
# first name: ['Hartley']
# except except : CHRISTAKOS G HARTLEY 'W'
# first name: ['Hristopoulos']
# except except : CHRISTAKOS G HRISTOPOULOS 'D.'
# first name: ['ICRCL']
# except except : CHRISTAKOS G ICRCL NONE
# first name: ['James']
# except except : CHRISTAKOS G JAMES 'BR'
# first name: ['Journel']
# except except : CHRISTAKOS G JOURNEL 'A.G.'
# first name: ['Kabata-Pendias']
# except except : CHRISTAKOS G KABATA-PENDIAS 'A.'
# first name: ['Kavouridis']
# except except : CHRISTAKOS G KAVOURIDIS 'K'
# first name: ['Kolovos']
# except except : CHRISTAKOS G KOLOVOS 'N'
# first name: ['Komnitsas']
# except except : CHRISTAKOS G KOMNITSAS 'K'
# first name: ['Komnitsas']
# try: CHRISTAKOS G KOMNITSAS 'K'
# first name: ['Modis']
# except except : CHRISTAKOS G MODIS 'K'
# first name: ['Modis']
# except except : CHRISTAKOS G MODIS 'K.'
# first name: ['Nielsen']
# except except : CHRISTAKOS G NIELSEN 'F.'
# first name: ['Orem']
# except except :
#  CHRISTAKOS G OREM 'W.'
# first name: ['PAVLIDES']
# except except : CHRISTAKOS G PAVLIDES 'SB'
# first name: ['Pentari']
# except except : CHRISTAKOS G PENTARI 'D'
# first name: ['Petrotou']
# except except : CHRISTAKOS G PETROTOU 'A.'
# first name: ['Pills']
# except except : CHRISTAKOS G PILLS 'J.'
# first name: ['Rose']
# except except : CHRISTAKOS G ROSE 'A.'
# first name: ['Sadiq']
# except except : CHRISTAKOS G SADIQ 'M'
# first name: ['Serre']
# except except : CHRISTAKOS G SERRE 'ML'
# first name: ['Snakin']
# except except : CHRISTAKOS G SNAKIN 'VV'
# first name: ['Swaine']
# except except : CHRISTAKOS G SWAINE 'D.'
# first name: ['Swaine']
# try: CHRISTAKOS G SWAINE 'D.'
# first name: ['Swaine']
# except except : CHRISTAKOS G SWAINE 'DJ'
# first name: ['Sylaios']
# except except : CHRISTAKOS G SYLAIOS 'G'
# first name: ['Tang']
# except except : CHRISTAKOS G TANG 'JC'
# first name: ['Triantafyllou']
# except except : CHRISTAKOS G TRIANTAFYLLOU 'AG'
# first name: ['Vatalis']
# except except : CHRISTAKOS G VATALIS 'K.'
# first name: ['Vatalis']
# except except : CHRISTAKOS G VATALIS 'KI'
# first name: ['Vatalis']
# try: CHRISTAKOS G VATALIS 'KI'
# first name: ['Xiao']
# except except : CHRISTAKOS G XIAO 'HY'
# first name: ['Yu']
# except except : CHRISTAKOS G YU 'HL'
# main name --- i: ['Christakos']
# first name: ['Clark']
# try: CHRISTAKOS G. CLARK 'L.'
# first name: ['Crnkovic']
# try: CHRISTAKOS G. CRNKOVIC 'D'
# first name: ['Dang']
# try: CHRISTAKOS G. DANG 'Z'
# first name: ['Dawes']
# try: CHRISTAKOS G. DAWES 'A'
# first name: ['Dimitrakopoulos']
# try: CHRISTAKOS G. DIMITRAKOPOULOS 'D.'
# first name: ['DUDAS']
# try: CHRISTAKOS G. DUDAS 'MJ'
# first name: ['Harmeling']
# try: CHRISTAKOS G. HARMELING 'S'
# first name: ['Hodge']
# try: CHRISTAKOS G. HODGE 'VJ'
# first name: ['Hotelling']
# try: CHRISTAKOS G. HOTELLING 'H.'
# first name: ['Juszczak']
# try: CHRISTAKOS G. JUSZCZAK 'P'
# first name: ['Kang']
# try: CHRISTAKOS G. KANG 'P'
# first name: ['Kang']
# try: CHRISTAKOS G. KANG 'P'
# first name: ['Environmental']
# try: CHRISTAKOS G. ENVIRONMENTAL 'PROTECTION'
# first name: ['FAO']
# try: CHRISTAKOS G. FAO ''
# first name: ['FILIPPIDIS']
# try: CHRISTAKOS G. FILIPPIDIS 'A'
# first name: ['Finkelman']
# try: CHRISTAKOS G. FINKELMAN 'R.B.'
# first name: ['Georgakopoulos']
# try: CHRISTAKOS G. GEORGAKOPOULOS 'A.'
# first name: ['Gerouki']
# try: CHRISTAKOS G. GEROUKI 'F.'
# first name: ['HART']
# try: CHRISTAKOS G. HART 'JD'
# first name: ['Hartley']
# try: CHRISTAKOS G. HARTLEY 'W'
# first name: ['Hristopoulos']
# try: CHRISTAKOS G. HRISTOPOULOS 'D.'
# first name: ['ICRCL']
# try: CHRISTAKOS G. ICRCL NONE
# first name: ['James']
# try: CHRISTAKOS G. JAMES 'BR'
# first name: ['Journel']
# try: CHRISTAKOS G. JOURNEL 'A.G.'
# first name: ['Kabata-Pendias']
# try: CHRISTAKOS G. KABATA-PENDIAS 'A.'
# first name: ['Kavouridis']
# try: CHRISTAKOS G. KAVOURIDIS 'K'
# first name: ['Kolovos']
# try: CHRISTAKOS G. KOLOVOS 'N'
# first name: ['Komnitsas']
# try: CHRISTAKOS G. KOMNITSAS 'K'
# first name: ['Komnitsas']
# try: CHRISTAKOS G. KOMNITSAS 'K'
# first name: ['Modis']
# try: CHRISTAKOS G. MODIS 'K'
# first name: ['Modis']
# try: CHRISTAKOS G. MODIS 'K.'
# first name: ['Nielsen']
# try: CHRISTAKOS G. NIELSEN 'F.'
# first name: ['Orem']
# try: CHRISTAKOS G. OREM 'W.'
# first name: ['PAVLIDES']
# try: CHRISTAKOS G. PAVLIDES 'SB'
# first name: ['Pentari']
# try: CHRISTAKOS G. PENTARI 'D'
# first name: ['Petrotou']
# try: CHRISTAKOS G. PETROTOU 'A.'
# first name: ['Pills']
# try: CHRISTAKOS G. PILLS 'J.'
# first name: ['Rose']
# try: CHRISTAKOS G. ROSE 'A.'
# first name: ['Sadiq']
# try: CHRISTAKOS G. SADIQ 'M'
# first name: ['Serre']
# try: CHRISTAKOS G. SERRE 'ML'
# first name: ['Snakin']
# try: CHRISTAKOS G. SNAKIN 'VV'
# first name: ['Swaine']
# try: CHRISTAKOS G. SWAINE 'D.'
# first name: ['Swaine']
# try: CHRISTAKOS G. SWAINE 'D.'
# first name: ['Swaine']
# try: CHRISTAKOS G. SWAINE 'DJ'
# first name: ['Sylaios']
# try: CHRISTAKOS G. SYLAIOS 'G'
# first name: ['Tang']
# try: CHRISTAKOS G. TANG 'JC'
# first name: ['Triantafyllou']
# try: CHRISTAKOS G. TRIANTAFYLLOU 'AG'
# first name: ['Vatalis']
# try: CHRISTAKOS G. VATALIS 'K.'
# first name: ['Vatalis']
# try: CHRISTAKOS G. VATALIS 'KI'
# first name: ['Vatalis']
# try: CHRISTAKOS G. VATALIS 'KI'
# first name: ['Xiao']
# try: CHRISTAKOS G. XIAO 'HY'
# first name: ['Yu']
# try: CHRISTAKOS G. YU 'HL'
# main name --- i: ['Clark']
# first name: ['Crnkovic']
# except except : CLARK L. CRNKOVIC 'D'
# first name: ['Dang']
# except except : CLARK L. DANG 'Z'
# first name: ['Dawes']
# except except : CLARK L. DAWES 'A'
# first name: ['Dimitrakopoulos']
# except except : CLARK L. DIMITRAKOPOULOS 'D.'
# first name: ['DUDAS']
# except except : CLARK L. DUDAS 'MJ'
# first name: ['Harmeling']
# except except : CLARK L. HARMELING 'S'
# first name: ['Hodge']
# except except : CLARK L. HODGE 'VJ'
# first name: ['Hotelling']
# except except : CLARK L. HOTELLING 'H.'
# first name: ['Juszczak']
# except except : CLARK L. JUSZCZAK 'P'
# first name: ['Kang']
# except except : CLARK L. KANG 'P'
# first name: ['Kang']
# try: CLARK L. KANG 'P'
# first name: ['Environmental']
# except except : CLARK L. ENVIRONMENTAL 'PROTECTION'
# first name: ['FAO']
# except except : CLARK L. FAO ''
# first name: ['FILIPPIDIS']
# except except : CLARK L. FILIPPIDIS 'A'
# first name: ['Finkelman']
# except except : CLARK L. FINKELMAN 'R.B.'
# first name: ['Georgakopoulos']
# except except : CLARK L. GEORGAKOPOULOS 'A.'
# first name: ['Gerouki']
# except except : CLARK L. GEROUKI 'F.'
# first name: ['HART']
# except except : CLARK L. HART 'JD'
# first name: ['Hartley']
# except except : CLARK L. HARTLEY 'W'
# first name: ['Hristopoulos']
# except except : CLARK L. HRISTOPOULOS 'D.'
# first name: ['ICRCL']
# except except : CLARK L. ICRCL NONE
# first name: ['James']
# except except : CLARK L. JAMES 'BR'
# first name: ['Journel']
# except except : CLARK L. JOURNEL 'A.G.'
# first name: ['Kabata-Pendias']
# except except : CLARK L. KABATA-PENDIAS 'A.'
# first name: ['Kavouridis']
# except except : CLARK L. KAVOURIDIS 'K'
# first name: ['Kolovos']
# except except : CLARK L. KOLOVOS 'N'
# first name: ['Komnitsas']
# except except : CLARK L. KOMNITSAS 'K'
# first name: ['Komnitsas']
# try: CLARK L. KOMNITSAS 'K'
# first name: ['Modis']
# except except : CLARK L. MODIS 'K'
# first name: ['Modis']
# except except : CLARK L. MODIS 'K.'
# first name: ['Nielsen']
# except except : CLARK L. NIELSEN 'F.'
# first name: ['Orem']
# except except : CLARK L. OREM 'W.'
# first name: ['PAVLIDES']
# except except : CLARK L. PAVLIDES 'SB'
# first name: ['Pentari']
# except except : CLARK L. PENTARI 'D'
# first name: ['Petrotou']
# except except : CLARK L. PETROTOU 'A.'
# first name: ['Pills']
# except except : CLARK L. PILLS 'J.'
# first name: ['Rose']
# except except : CLARK L. ROSE 'A.'
# first name: ['Sadiq']
# except except : CLARK L. SADIQ 'M'
# first name: ['Serre']
# except except : CLARK L. SERRE 'ML'
# first name: ['Snakin']
# except except : CLARK L. SNAKIN 'VV'
# first name: ['Swaine']
# except except : CLARK L. SWAINE 'D.'
# first name: ['Swaine']
# try: CLARK L. SWAINE 'D.'
# first name: ['Swaine']
# except except : CLARK L. SWAINE 'DJ'
# first name: ['Sylaios']
# except except : CLARK L. SYLAIOS 'G'
# first name: ['Tang']
# except except : CLARK L. TANG 'JC'
# first name: ['Triantafyllou']
# except except : CLARK L. TRIANTAFYLLOU 'AG'
# first name: ['Vatalis']
# except except : CLARK L. VATALIS 'K.'
# first name: ['Vatalis']
# except except : CLARK L. VATALIS 'KI'
# first name: ['Vatalis']
# try: CLARK L. VATALIS 'KI'
# first name: ['Xiao']
# except except : CLARK L. XIAO 'HY'
# first name: ['Yu']
# except except : CLARK L. YU 'HL'
# main name --- i: ['Crnkovic']
# first name: ['Dang']
# except except : CRNKOVIC D DANG 'Z'
# first name: ['Dawes']
# except except : CRNKOVIC D DAWES 'A'
# first name: ['Dimitrakopoulos']
# except except : CRNKOVIC D DIMITRAKOPOULOS 'D.'
# first name: ['DUDAS']
# except except : CRNKOVIC D DUDAS 'MJ'
# first name: ['Harmeling']
# except except : CRNKOVIC D HARMELING 'S'
# first name: ['Hodge']
# except except : CRNKOVIC D HODGE 'VJ'
# first name: ['Hotelling']
# except except : CRNKOVIC D HOTELLING 'H.'
# first name: ['Juszczak']
# except except : CRNKOVIC D JUSZCZAK 'P'
# first name: ['Kang']
# except except : CRNKOVIC D KANG 'P'
# first name: ['Kang']
# try: CRNKOVIC D KANG 'P'
# first name: ['Environmental']
# except except : CRNKOVIC D ENVIRONMENTAL 'PROTECTION'
# first name: ['FAO']
# except except : CRNKOVIC D FAO ''
# first name: ['FILIPPIDIS']
# except except : CRNKOVIC D FILIPPIDIS 'A'
# first name: ['Finkelman']
# except except : CRNKOVIC D FINKELMAN 'R.B.'
# first name: ['Georgakopoulos']
# except except : CRNKOVIC D GEORGAKOPOULOS 'A.'
# first name: ['Gerouki']
# except except : CRNKOVIC D GEROUKI 'F.'
# first name: ['HART']
# except except : CRNKOVIC D HART 'JD'
# first name: ['Hartley']
# except except : CRNKOVIC D HARTLEY 'W'
# first name: ['Hristopoulos']
# except except : CRNKOVIC D HRISTOPOULOS 'D.'
# first name: ['ICRCL']
# except except : CRNKOVIC D ICRCL NONE
# first name: ['James']
# except except : CRNKOVIC D JAMES 'BR'
# first name: ['Journel']
# except except : CRNKOVIC D JOURNEL 'A.G.'
# first name: ['Kabata-Pendias']
# except except : CRNKOVIC D KABATA-PENDIAS 'A.'
# first name: ['Kavouridis']
# except except : CRNKOVIC D KAVOURIDIS 'K'
# first name: ['Kolovos']
# except except : CRNKOVIC D KOLOVOS 'N'
# first name: ['Komnitsas']
# except except : CRNKOVIC D KOMNITSAS 'K'
# first name: ['Komnitsas']
# try: CRNKOVIC D KOMNITSAS 'K'
# first name: ['Modis']
# except except : CRNKOVIC D MODIS 'K'
# first name: ['Modis']
# except except : CRNKOVIC D MODIS 'K.'
# first name: ['Nielsen']
# except except : CRNKOVIC D NIELSEN 'F.'
# first name: ['Orem']
# except except : CRNKOVIC D OREM 'W.'
# first name: ['PAVLIDES']
# except except : CRNKOVIC D PAVLIDES 'SB'
# first name: ['Pentari']
# except except : CRNKOVIC D PENTARI 'D'
# first name: ['Petrotou']
# except except : CRNKOVIC D PETROTOU 'A.'
# first name: ['Pills']
# except except : CRNKOVIC D PILLS 'J.'
# first name: ['Rose']
# except except : CRNKOVIC D ROSE 'A.'
# first name: ['Sadiq']
# except except : CRNKOVIC D SADIQ 'M'
# first name: ['Serre']
# except except : CRNKOVIC D SERRE 'ML'
# first name: ['Snakin']
# except except : CRNKOVIC D SNAKIN 'VV'
# first name: ['Swaine']
# except except : CRNKOVIC D SWAINE 'D.'
# first name: ['Swaine']
# try: CRNKOVIC D SWAINE 'D.'
# first name: ['Swaine']
# except except : CRNKOVIC D SWAINE 'DJ'
# first name: ['Sylaios']
# except except : CRNKOVIC D SYLAIOS 'G'
# first name: ['Tang']
# except except : CRNKOVIC D TANG 'JC'
# first name: ['Triantafyllou']
# except except : CRNKOVIC D TRIANTAFYLLOU 'AG'
# first name: ['Vatalis']
# except except : CRNKOVIC D VATALIS 'K.'
# first name: ['Vatalis']
# except except : CRNKOVIC D VATALIS 'KI'
# first name: ['Vatalis']
# try: CRNKOVIC D VATALIS 'KI'
# first name: ['Xiao']
# except except : CRNKOVIC D XIAO 'HY'
# first name: ['Yu']
# except except : CRNKOVIC D YU 'HL'
# main name --- i: ['Dang']
# first name: ['Dawes']
# except except : DANG Z DAWES 'A'
# first name: ['Dimitrakopoulos']
# except except : DANG Z DIMITRAKOPOULOS 'D.'
# first name: ['DUDAS']
# except except : DANG Z DUDAS 'MJ'
# first name: ['Harmeling']
# except except : DANG Z HARMELING 'S'
# first name: ['Hodge']
# except except : DANG Z HODGE 'VJ'
# first name: ['Hotelling']
# except except : DANG Z HOTELLING 'H.'
# first name: ['Juszczak']
# except except : DANG Z JUSZCZAK 'P'
# first name: ['Kang']
# except except : DANG Z KANG 'P'
# first name: ['Kang']
# try: DANG Z KANG 'P'
# first name: ['Environmental']
# except except : DANG Z ENVIRONMENTAL 'PROTECTION'
# first name: ['FAO']
# except except : DANG Z FAO ''
# first name: ['FILIPPIDIS']
# except except : DANG Z FILIPPIDIS 'A'
# first name: ['Finkelman']
# except except : DANG Z FINKELMAN 'R.B.'
# first name: ['Georgakopoulos']
# except except : DANG Z GEORGAKOPOULOS 'A.'
# first name: ['Gerouki']
# except except : DANG Z GEROUKI 'F.'
# first name: ['HART']
# except except : DANG Z HART 'JD'
# first name: ['Hartley']
# except except : DANG Z HARTLEY 'W'
# first name: ['Hristopoulos']
# except except : DANG Z HRISTOPOULOS 'D.'
# first name: ['ICRCL']
# except except : DANG Z ICRCL NONE
# first name: ['James']
# except except : DANG Z JAMES 'BR'
# first name: ['Journel']
# except except : DANG Z JOURNEL 'A.G.'
# first name: ['Kabata-Pendias']
# except except : DANG Z KABATA-PENDIAS 'A.'
# first name:
#  ['Kavouridis']
# except except : DANG Z KAVOURIDIS 'K'
# first name: ['Kolovos']
# except except : DANG Z KOLOVOS 'N'
# first name: ['Komnitsas']
# except except : DANG Z KOMNITSAS 'K'
# first name: ['Komnitsas']
# try: DANG Z KOMNITSAS 'K'
# first name: ['Modis']
# except except : DANG Z MODIS 'K'
# first name: ['Modis']
# except except : DANG Z MODIS 'K.'
# first name: ['Nielsen']
# except except : DANG Z NIELSEN 'F.'
# first name: ['Orem']
# except except : DANG Z OREM 'W.'
# first name: ['PAVLIDES']
# except except : DANG Z PAVLIDES 'SB'
# first name: ['Pentari']
# except except : DANG Z PENTARI 'D'
# first name: ['Petrotou']
# except except : DANG Z PETROTOU 'A.'
# first name: ['Pills']
# except except : DANG Z PILLS 'J.'
# first name: ['Rose']
# except except : DANG Z ROSE 'A.'
# first name: ['Sadiq']
# except except : DANG Z SADIQ 'M'
# first name: ['Serre']
# except except : DANG Z SERRE 'ML'
# first name: ['Snakin']
# except except : DANG Z SNAKIN 'VV'
# first name: ['Swaine']
# except except : DANG Z SWAINE 'D.'
# first name: ['Swaine']
# try: DANG Z SWAINE 'D.'
# first name: ['Swaine']
# except except : DANG Z SWAINE 'DJ'
# first name: ['Sylaios']
# except except : DANG Z SYLAIOS 'G'
# first name: ['Tang']
# except except : DANG Z TANG 'JC'
# first name: ['Triantafyllou']
# except except : DANG Z TRIANTAFYLLOU 'AG'
# first name: ['Vatalis']
# except except : DANG Z VATALIS 'K.'
# first name: ['Vatalis']
# except except : DANG Z VATALIS 'KI'
# first name: ['Vatalis']
# try: DANG Z VATALIS 'KI'
# first name: ['Xiao']
# except except : DANG Z XIAO 'HY'
# first name: ['Yu']
# except except : DANG Z YU 'HL'
# main name --- i: ['Dawes']
# first name: ['Dimitrakopoulos']
# except except : DAWES A DIMITRAKOPOULOS 'D.'
# first name: ['DUDAS']
# except except : DAWES A DUDAS 'MJ'
# first name: ['Harmeling']
# except except : DAWES A HARMELING 'S'
# first name: ['Hodge']
# except except : DAWES A HODGE 'VJ'
# first name: ['Hotelling']
# except except : DAWES A HOTELLING 'H.'
# first name: ['Juszczak']
# except except : DAWES A JUSZCZAK 'P'
# first name: ['Kang']
# except except : DAWES A KANG 'P'
# first name: ['Kang']
# try: DAWES A KANG 'P'
# first name: ['Environmental']
# except except : DAWES A ENVIRONMENTAL 'PROTECTION'
# first name: ['FAO']
# except except : DAWES A FAO ''
# first name: ['FILIPPIDIS']
# except except : DAWES A FILIPPIDIS 'A'
# first name: ['Finkelman']
# except except : DAWES A FINKELMAN 'R.B.'
# first name: ['Georgakopoulos']
# except except : DAWES A GEORGAKOPOULOS 'A.'
# first name: ['Gerouki']
# except except : DAWES A GEROUKI 'F.'
# first name: ['HART']
# except except : DAWES A HART 'JD'
# first name: ['Hartley']
# except except : DAWES A HARTLEY 'W'
# first name: ['Hristopoulos']
# except except : DAWES A HRISTOPOULOS 'D.'
# first name: ['ICRCL']
# except except : DAWES A ICRCL NONE
# first name: ['James']
# except except : DAWES A JAMES 'BR'
# first name: ['Journel']
# except except : DAWES A JOURNEL 'A.G.'
# first name: ['Kabata-Pendias']
# except except : DAWES A KABATA-PENDIAS 'A.'
# first name: ['Kavouridis']
# except except : DAWES A KAVOURIDIS 'K'
# first name: ['Kolovos']
# except except : DAWES A KOLOVOS 'N'
# first name: ['Komnitsas']
# except except : DAWES A KOMNITSAS 'K'
# first name: ['Komnitsas']
# try: DAWES A KOMNITSAS 'K'
# first name: ['Modis']
# except except : DAWES A MODIS 'K'
# first name: ['Modis']
# except except : DAWES A MODIS 'K.'
# first name: ['Nielsen']
# except except : DAWES A NIELSEN 'F.'
# first name: ['Orem']
# except except : DAWES A OREM 'W.'
# first name: ['PAVLIDES']
# except except : DAWES A PAVLIDES 'SB'
# first name: ['Pentari']
# except except : DAWES A PENTARI 'D'
# first name: ['Petrotou']
# except except : DAWES A PETROTOU 'A.'
# first name: ['Pills']
# except except : DAWES A PILLS 'J.'
# first name: ['Rose']
# except except : DAWES A ROSE 'A.'
# first name: ['Sadiq']
# except except : DAWES A SADIQ 'M'
# first name: ['Serre']
# except except : DAWES A SERRE 'ML'
# first name: ['Snakin']
# except except : DAWES A SNAKIN 'VV'
# first name: ['Swaine']
# except except : DAWES A SWAINE 'D.'
# first name: ['Swaine']
# try: DAWES A SWAINE 'D.'
# first name: ['Swaine']
# except except : DAWES A SWAINE 'DJ'
# first name: ['Sylaios']
# except except : DAWES A SYLAIOS 'G'
# first name: ['Tang']
# except except : DAWES A TANG 'JC'
# first name: ['Triantafyllou']
# except except : DAWES A TRIANTAFYLLOU 'AG'
# first name: ['Vatalis']
# except except : DAWES A VATALIS 'K.'
# first name: ['Vatalis']
# except except : DAWES A VATALIS 'KI'
# first name: ['Vatalis']
# try: DAWES A VATALIS 'KI'
# first name: ['Xiao']
# except except : DAWES A XIAO 'HY'
# first name: ['Yu']
# except except : DAWES A YU 'HL'
# main name --- i: ['Dimitrakopoulos']
# first name: ['DUDAS']
# except except : DIMITRAKOPOULOS D. DUDAS 'MJ'
# first name: ['Harmeling']
# except except : DIMITRAKOPOULOS D. HARMELING 'S'
# first name: ['Hodge']
# except except : DIMITRAKOPOULOS D. HODGE 'VJ'
# first name: ['Hotelling']
# except except : DIMITRAKOPOULOS D. HOTELLING 'H.'
# first name: ['Juszczak']
# except except : DIMITRAKOPOULOS D. JUSZCZAK 'P'
# first name: ['Kang']
# except except : DIMITRAKOPOULOS D. KANG 'P'
# first name: ['Kang']
# try: DIMITRAKOPOULOS D. KANG 'P'
# first name: ['Environmental']
# except except : DIMITRAKOPOULOS D. ENVIRONMENTAL 'PROTECTION'
# first name: ['FAO']
# except except : DIMITRAKOPOULOS D. FAO ''
# first name: ['FILIPPIDIS']
# except except : DIMITRAKOPOULOS D. FILIPPIDIS 'A'
# first name: ['Finkelman']
# except except : DIMITRAKOPOULOS D. FINKELMAN 'R.B.'
# first name: ['Georgakopoulos']
# except except : DIMITRAKOPOULOS D. GEORGAKOPOULOS 'A.'
# first name: ['Gerouki']
# except except : DIMITRAKOPOULOS D. GEROUKI 'F.'
# first name: ['HART']
# except except : DIMITRAKOPOULOS D. HART 'JD'
# first name: ['Hartley']
# except except : DIMITRAKOPOULOS D. HARTLEY 'W'
# first name: ['Hristopoulos']
# except except : DIMITRAKOPOULOS D. HRISTOPOULOS 'D.'
# first name: ['ICRCL']
# except except : DIMITRAKOPOULOS D. ICRCL NONE
# first name: ['James']
# except except : DIMITRAKOPOULOS D. JAMES 'BR'
# first name: ['Journel']
# except except : DIMITRAKOPOULOS D. JOURNEL 'A.G.'
# first name: ['Kabata-Pendias']
# except except : DIMITRAKOPOULOS D. KABATA-PENDIAS 'A.'
# first name: ['Kavouridis']
# except except : DIMITRAKOPOULOS D. KAVOURIDIS 'K'
# first name: ['Kolovos']
# except except : DIMITRAKOPOULOS D. KOLOVOS 'N'
# first name: ['Komnitsas']
# except except : DIMITRAKOPOULOS D. KOMNITSAS 'K'
# first name: ['Komnitsas']
# try: DIMITRAKOPOULOS D. KOMNITSAS 'K'
# first name: ['Modis']
# except except : DIMITRAKOPOULOS D. MODIS 'K'
# first name: ['Modis']
# except except : DIMITRAKOPOULOS D. MODIS 'K.'
# first name: ['Nielsen']
# except except : DIMITRAKOPOULOS D. NIELSEN 'F.'
# first name: ['Orem']
# except except : DIMITRAKOPOULOS D. OREM 'W.'
# first name: ['PAVLIDES']
# except except : DIMITRAKOPOULOS D. PAVLIDES 'SB'
# first name: ['Pentari']
# except except : DIMITRAKOPOULOS D. PENTARI 'D'
# first name: ['Petrotou']
# except except : DIMITRAKOPOULOS D. PETROTOU 'A.'
# first name: ['Pills']
# except except : DIMITRAKOPOULOS D. PILLS 'J.'
# first name: ['Rose']
# except except : DIMITRAKOPOULOS D. ROSE 'A.'
# first name: ['Sadiq']
# except except : DIMITRAKOPOULOS D. SADIQ 'M'
# first name: ['Serre']
# except except : DIMITRAKOPOULOS D. SERRE 'ML'
# first name: ['Snakin']
# except except : DIMITRAKOPOULOS D. SNAKIN 'VV'
# first name: ['Swaine']
# except except : DIMITRAKOPOULOS D. SWAINE 'D.'
# first name: ['Swaine']
# try: DIMITRAKOPOULOS D. SWAINE 'D.'
# first name: ['Swaine']
# except except : DIMITRAKOPOULOS D. SWAINE 'DJ'
# first name: ['Sylaios']
# except except : DIMITRAKOPOULOS D. SYLAIOS 'G'
# first name: ['Tang']
# except except : DIMITRAKOPOULOS D. TANG 'JC'
# first name: ['Triantafyllou']
# except except : DIMITRAKOPOULOS D. TRIANTAFYLLOU 'AG'
# first name: ['Vatalis']
# except except : DIMITRAKOPOULOS D. VATALIS 'K.'
# first name: ['Vatalis']
# except except : DIMITRAKOPOULOS D. VATALIS 'KI'
# first name: ['Vatalis']
# try: DIMITRAKOPOULOS D. VATALIS 'KI'
# first name: ['Xiao']
# except except : DIMITRAKOPOULOS D. XIAO 'HY'
# first name: ['Yu']
# except except : DIMITRAKOPOULOS D. YU 'HL'
# main name --- i: ['DUDAS']
# first name: ['Harmeling']
# except except : DUDAS MJ HARMELING 'S'
# first name: ['Hodge']
# except except : DUDAS MJ HODGE 'VJ'
# first name: ['Hotelling']
# except except : DUDAS MJ HOTELLING 'H.'
# first name: ['Juszczak']
# except except : DUDAS MJ JUSZCZAK 'P'
# first name: ['Kang']
# except except : DUDAS MJ KANG 'P'
# first name: ['Kang']
# try: DUDAS MJ KANG 'P'
# first name: ['Environmental']
# except except : DUDAS MJ ENVIRONMENTAL 'PROTECTION'
# first name: ['FAO']
# except except : DUDAS MJ FAO ''
# first name: ['FILIPPIDIS']
# except except : DUDAS MJ FILIPPIDIS 'A'
# first name: ['Finkelman']
# except except : DUDAS MJ FINKELMAN 'R.B.'
# first name: ['Georgakopoulos']
# except except : DUDAS MJ GEORGAKOPOULOS 'A.'
# first name: ['Gerouki']
# except except : DUDAS MJ GEROUKI 'F.'
# first name: ['HART']
# except except : DUDAS MJ HART 'JD'
# first name: ['Hartley']
# except except : DUDAS MJ HARTLEY 'W'
# first name:
# ['Hristopoulos']
# except except : DUDAS MJ HRISTOPOULOS 'D.'
# first name: ['ICRCL']
# except except : DUDAS MJ ICRCL NONE
# first name: ['James']
# except except : DUDAS MJ JAMES 'BR'
# first name: ['Journel']
# except except : DUDAS MJ JOURNEL 'A.G.'
# first name: ['Kabata-Pendias']
# except except : DUDAS MJ KABATA-PENDIAS 'A.'
# first name: ['Kavouridis']
# except except : DUDAS MJ KAVOURIDIS 'K'
# first name: ['Kolovos']
# except except : DUDAS MJ KOLOVOS 'N'
# first name: ['Komnitsas']
# except except : DUDAS MJ KOMNITSAS 'K'
# first name: ['Komnitsas']
# try: DUDAS MJ KOMNITSAS 'K'
# first name: ['Modis']
# except except : DUDAS MJ MODIS 'K'
# first name: ['Modis']
# except except : DUDAS MJ MODIS 'K.'
# first name: ['Nielsen']
# except except : DUDAS MJ NIELSEN 'F.'
# first name: ['Orem']
# except except : DUDAS MJ OREM 'W.'
# first name: ['PAVLIDES']
# except except : DUDAS MJ PAVLIDES 'SB'
# first name: ['Pentari']
# except except : DUDAS MJ PENTARI 'D'
# first name: ['Petrotou']
# except except : DUDAS MJ PETROTOU 'A.'
# first name: ['Pills']
# except except : DUDAS MJ PILLS 'J.'
# first name: ['Rose']
# except except : DUDAS MJ ROSE 'A.'
# first name: ['Sadiq']
# except except : DUDAS MJ SADIQ 'M'
# first name: ['Serre']
# except except : DUDAS MJ SERRE 'ML'
# first name: ['Snakin']
# except except : DUDAS MJ SNAKIN 'VV'
# first name: ['Swaine']
# except except : DUDAS MJ SWAINE 'D.'
# first name: ['Swaine']
# try: DUDAS MJ SWAINE 'D.'
# first name: ['Swaine']
# except except : DUDAS MJ SWAINE 'DJ'
# first name: ['Sylaios']
# except except : DUDAS MJ SYLAIOS 'G'
# first name: ['Tang']
# except except : DUDAS MJ TANG 'JC'
# first name: ['Triantafyllou']
# except except : DUDAS MJ TRIANTAFYLLOU 'AG'
# first name: ['Vatalis']
# except except : DUDAS MJ VATALIS 'K.'
# first name: ['Vatalis']
# except except : DUDAS MJ VATALIS 'KI'
# first name: ['Vatalis']
# try: DUDAS MJ VATALIS 'KI'
# first name: ['Xiao']
# except except : DUDAS MJ XIAO 'HY'
# first name: ['Yu']
# except except : DUDAS MJ YU 'HL'
# main name --- i: ['Harmeling']
# first name: ['Hodge']
# except except : HARMELING S HODGE 'VJ'
# first name: ['Hotelling']
# except except : HARMELING S HOTELLING 'H.'
# first name: ['Juszczak']
# except except : HARMELING S JUSZCZAK 'P'
# first name: ['Kang']
# except except : HARMELING S KANG 'P'
# first name: ['Kang']
# try: HARMELING S KANG 'P'
# first name: ['Environmental']
# except except : HARMELING S ENVIRONMENTAL 'PROTECTION'
# first name: ['FAO']
# except except : HARMELING S FAO ''
# first name: ['FILIPPIDIS']
# except except : HARMELING S FILIPPIDIS 'A'
# first name: ['Finkelman']
# except except : HARMELING S FINKELMAN 'R.B.'
# first name: ['Georgakopoulos']
# except except : HARMELING S GEORGAKOPOULOS 'A.'
# first name: ['Gerouki']
# except except : HARMELING S GEROUKI 'F.'
# first name: ['HART']
# except except : HARMELING S HART 'JD'
# first name: ['Hartley']
# except except : HARMELING S HARTLEY 'W'
# first name: ['Hristopoulos']
# except except : HARMELING S HRISTOPOULOS 'D.'
# first name: ['ICRCL']
# except except : HARMELING S ICRCL NONE
# first name: ['James']
# except except : HARMELING S JAMES 'BR'
# first name: ['Journel']
# except except : HARMELING S JOURNEL 'A.G.'
# first name: ['Kabata-Pendias']
# except except : HARMELING S KABATA-PENDIAS 'A.'
# first name: ['Kavouridis']
# except except : HARMELING S KAVOURIDIS 'K'
# first name: ['Kolovos']
# except except : HARMELING S KOLOVOS 'N'
# first name: ['Komnitsas']
# except except : HARMELING S KOMNITSAS 'K'
# first name: ['Komnitsas']
# try: HARMELING S KOMNITSAS 'K'
# first name: ['Modis']
# except except : HARMELING S MODIS 'K'
# first name: ['Modis']
# except except : HARMELING S MODIS 'K.'
# first name: ['Nielsen']
# except except : HARMELING S NIELSEN 'F.'
# first name: ['Orem']
# except except : HARMELING S OREM 'W.'
# first name: ['PAVLIDES']
# except except : HARMELING S PAVLIDES 'SB'
# first name: ['Pentari']
# except except : HARMELING S PENTARI 'D'
# first name: ['Petrotou']
# except except : HARMELING S PETROTOU 'A.'
# first name: ['Pills']
# except except : HARMELING S PILLS 'J.'
# first name: ['Rose']
# except except : HARMELING S ROSE 'A.'
# first name: ['Sadiq']
# except except : HARMELING S SADIQ 'M'
# ...
# first name: ['Kabata-Pendias']
# except except : FILIPPIDIS A KABATA-PENDIAS 'A.'
# first name: ['Kavouridis']
# except except : FILIPPIDIS A KAVOURIDIS 'K'
# first name: ['Kolovos']
# except except : FILIPPIDIS A KOLOVOS 'N'
# first name: ['Komnitsas']
# except except : FILIPPIDIS A KOMNITSAS 'K'
# first name: ['Komnitsas']
# try: FILIPPIDIS A KOMNITSAS 'K'
# first name: ['Modis']
# except except : FILIPPIDIS A MODIS 'K'
# first name: ['Modis']
# except except : FILIPPIDIS A MODIS 'K.'
# first name: ['Nielsen']
# except except : FILIPPIDIS A NIELSEN 'F.'
# first name: ['Orem']
# except except : FILIPPIDIS A OREM 'W.'
# first name: ['PAVLIDES']
# except except : FILIPPIDIS A PAVLIDES 'SB'
# first name: ['Pentari']
# except except : FILIPPIDIS A PENTARI 'D'
# first name: ['Petrotou']
# except except : FILIPPIDIS A PETROTOU 'A.'
# first name: ['Pills']
# except except : FILIPPIDIS A PILLS 'J.'
# first name: ['Rose']
# except except : FILIPPIDIS A ROSE 'A.'
# first name: ['Sadiq']
# except except : FILIPPIDIS A SADIQ 'M'
# first name: ['Serre']
# except except : FILIPPIDIS A SERRE 'ML'
# first name: ['Snakin']
# except except : FILIPPIDIS A SNAKIN 'VV'
# first name: ['Swaine']
# except except : FILIPPIDIS A SWAINE 'D.'
# first name: ['Swaine']
# try: FILIPPIDIS A SWAINE 'D.'
# first name: ['Swaine']
# except except : FILIPPIDIS A SWAINE 'DJ'
# first name: ['Sylaios']
# except except : FILIPPIDIS A SYLAIOS 'G'
# first name: ['Tang']
# except except : FILIPPIDIS A TANG 'JC'
# first name: ['Triantafyllou']
# except except : FILIPPIDIS A TRIANTAFYLLOU 'AG'
# first name: ['Vatalis']
# except except : FILIPPIDIS A VATALIS 'K.'
# first name: ['Vatalis']
# except except : FILIPPIDIS A VATALIS 'KI'
# first name: ['Vatalis']
# try: FILIPPIDIS A VATALIS 'KI'
# first name: ['Xiao']
# except except : FILIPPIDIS A XIAO 'HY'
# first name: ['Yu']
# except except : FILIPPIDIS A YU 'HL'
# main name --- i: ['Finkelman']
# first name: ['Georgakopoulos']
# except except : FINKELMAN R.B. GEORGAKOPOULOS 'A.'
# first name: ['Gerouki']
# except except : FINKELMAN R.B. GEROUKI 'F.'
# first name: ['HART']
# except except : FINKELMAN R.B. HART 'JD'
# first name: ['Hartley']
# except except : FINKELMAN R.B. HARTLEY 'W'
# first name: ['Hristopoulos']
# except except : FINKELMAN R.B. HRISTOPOULOS 'D.'
# first name: ['ICRCL']
# except except : FINKELMAN R.B. ICRCL NONE
# first name: ['James']
# except except : FINKELMAN R.B. JAMES 'BR'
# first name: ['Journel']
# except except : FINKELMAN R.B. JOURNEL 'A.G.'
# first name: ['Kabata-Pendias']
# except except : FINKELMAN R.B. KABATA-PENDIAS 'A.'
# first name: ['Kavouridis']
# except except : FINKELMAN R.B. KAVOURIDIS 'K'
# first name: ['Kolovos']
# except except : FINKELMAN R.B. KOLOVOS 'N'
# first name: ['Komnitsas']
# except except : FINKELMAN R.B. KOMNITSAS 'K'
# first name: ['Komnitsas']
# try: FINKELMAN R.B. KOMNITSAS 'K'
# first name: ['Modis']
# except except : FINKELMAN R.B. MODIS 'K'
# first name: ['Modis']
# except except : FINKELMAN R.B. MODIS 'K.'
# first name: ['Nielsen']
# except except : FINKELMAN R.B. NIELSEN 'F.'
# first name: ['Orem']
# except except : FINKELMAN R.B. OREM 'W.'
# first name: ['PAVLIDES']
# except except : FINKELMAN R.B. PAVLIDES 'SB'
# first name: ['Pentari']
# except except : FINKELMAN R.B. PENTARI 'D'
# first name: ['Petrotou']
# except except : FINKELMAN R.B. PETROTOU 'A.'
# first name: ['Pills']
# except except : FINKELMAN R.B. PILLS 'J.'
# first name: ['Rose']
# except except : FINKELMAN R.B. ROSE 'A.'
# first name: ['Sadiq']
# except except : FINKELMAN R.B. SADIQ 'M'
# first name: ['Serre']
# except except : FINKELMAN R.B. SERRE 'ML'
# first name: ['Snakin']
# except except : FINKELMAN R.B. SNAKIN 'VV'
# first name: ['Swaine']
# except except : FINKELMAN R.B. SWAINE 'D.'
# first name: ['Swaine']
# try: FINKELMAN R.B. SWAINE 'D.'
# first name: ['Swaine']
# except except : FINKELMAN R.B. SWAINE 'DJ'
# first name: ['Sylaios']
# except except : FINKELMAN R.B. SYLAIOS 'G'
# first name: ['Tang']
# except except : FINKELMAN R.B. TANG 'JC'
# first name: ['Triantafyllou']
# except except : FINKELMAN R.B. TRIANTAFYLLOU 'AG'
# first name: ['Vatalis']
# except except : FINKELMAN R.B. VATALIS 'K.'
# first name: ['Vatalis']
# except except : FINKELMAN R.B. VATALIS 'KI'
# first name: ['Vatalis']
# try: FINKELMAN R.B. VATALIS 'KI'
# first name: ['Xiao']
# except except : FINKELMAN R.B. XIAO 'HY'
# first name: ['Yu']
# except except : FINKELMAN R.B. YU 'HL'
# main name --- i: ['Georgakopoulos']
# first name: ['Gerouki']
# except except : GEORGAKOPOULOS A. GEROUKI 'F.'
# first name: ['HART']
# except except : GEORGAKOPOULOS A. HART 'JD'
# first name: ['Hartley']
# except except : GEORGAKOPOULOS A. HARTLEY 'W'
# first name: ['Hristopoulos']
# except except : GEORGAKOPOULOS A. HRISTOPOULOS 'D.'
# first name: ['ICRCL']
# except except : GEORGAKOPOULOS A. ICRCL NONE
# first name: ['James']
# except except : GEORGAKOPOULOS A. JAMES 'BR'
# first name: ['Journel']
# except except : GEORGAKOPOULOS A. JOURNEL 'A.G.'
# first name: ['Kabata-Pendias']
# except except : GEORGAKOPOULOS A. KABATA-PENDIAS 'A.'
# first name: ['Kavouridis']
# except except : GEORGAKOPOULOS A. KAVOURIDIS 'K'
# first name: ['Kolovos']
# except except : GEORGAKOPOULOS A. KOLOVOS 'N'
# first name: ['Komnitsas']
# except except : GEORGAKOPOULOS A. KOMNITSAS 'K'
# first name: ['Komnitsas']
# try: GEORGAKOPOULOS A. KOMNITSAS 'K'
# first name: ['Modis']
# except except : GEORGAKOPOULOS A. MODIS 'K'
# first name: ['Modis']
# except except : GEORGAKOPOULOS A. MODIS 'K.'
# first name: ['Nielsen']
# except except : GEORGAKOPOULOS A. NIELSEN 'F.'
# first name: ['Orem']
# except except : GEORGAKOPOULOS A. OREM 'W.'
# first name: ['PAVLIDES']
# except except : GEORGAKOPOULOS A. PAVLIDES 'SB'
# first name: ['Pentari']
# except except : GEORGAKOPOULOS A. PENTARI 'D'
# first name: ['Petrotou']
# except except : GEORGAKOPOULOS A. PETROTOU 'A.'
# first name: ['Pills']
# except except : GEORGAKOPOULOS A. PILLS 'J.'
# first name: ['Rose']
# except except : GEORGAKOPOULOS A. ROSE 'A.'
# first name: ['Sadiq']
# except except : GEORGAKOPOULOS A. SADIQ 'M'
# first name: ['Serre']
# except except : GEORGAKOPOULOS A. SERRE 'ML'
# first name: ['Snakin']
# except except : GEORGAKOPOULOS A. SNAKIN 'VV'
# first name: ['Swaine']
# except except : GEORGAKOPOULOS A. SWAINE 'D.'
# first name: ['Swaine']
# try: GEORGAKOPOULOS A. SWAINE 'D.'
# first name: ['Swaine']
# except except : GEORGAKOPOULOS A. SWAINE 'DJ'
# first name: ['Sylaios']
# except except : GEORGAKOPOULOS A. SYLAIOS 'G'
# first name: ['Tang']
# except except : GEORGAKOPOULOS A. TANG 'JC'
# first name: ['Triantafyllou']
# except except : GEORGAKOPOULOS A. TRIANTAFYLLOU 'AG'
# first name: ['Vatalis']
# except except : GEORGAKOPOULOS A. VATALIS 'K.'
# first name: ['Vatalis']
# except except : GEORGAKOPOULOS A. VATALIS 'KI'
# first name: ['Vatalis']
# try: GEORGAKOPOULOS A. VATALIS 'KI'
# first name: ['Xiao']
# except except : GEORGAKOPOULOS A. XIAO 'HY'
# first name: ['Yu']
# except except : GEORGAKOPOULOS A. YU 'HL'
# main name --- i: ['Gerouki']
# first name: ['HART']
# except except : GEROUKI F. HART 'JD'
# first name: ['Hartley']
# except except : GEROUKI F. HARTLEY 'W'
# first name: ['Hristopoulos']
# except except : GEROUKI F. HRISTOPOULOS 'D.'
# first name: ['ICRCL']
# except except : GEROUKI F. ICRCL NONE
# first name: ['James']
# except except : GEROUKI F. JAMES 'BR'
# first name: ['Journel']
# except except : GEROUKI F. JOURNEL 'A.G.'
# first name: ['Kabata-Pendias']
# except except : GEROUKI F. KABATA-PENDIAS 'A.'
# first name: ['Kavouridis']
# except except : GEROUKI F. KAVOURIDIS 'K'
# first name: ['Kolovos']
# except except : GEROUKI F. KOLOVOS 'N'
# first name: ['Komnitsas']
# except except : GEROUKI F. KOMNITSAS 'K'
# first name: ['Komnitsas']
# try: GEROUKI F. KOMNITSAS 'K'
# first name: ['Modis']
# except except : GEROUKI F. MODIS 'K'
# first name: ['Modis']
# except except : GEROUKI F. MODIS 'K.'
# first name: ['Nielsen']
# except except : GEROUKI F. NIELSEN 'F.'
# first name: ['Orem']
# except except : GEROUKI F. OREM 'W.'
# first name: ['PAVLIDES']
# except except : GEROUKI F. PAVLIDES 'SB'
# first name: ['Pentari']
# except except : GEROUKI F. PENTARI 'D'
# first name: ['Petrotou']
# except except : GEROUKI F. PETROTOU 'A.'
# first name: ['Pills']
# except except : GEROUKI F. PILLS 'J.'
# first name: ['Rose']
# except except : GEROUKI F. ROSE 'A.'
# first name: ['Sadiq']
# except except : GEROUKI F. SADIQ 'M'
# first name: ['Serre']
# except except : GEROUKI F. SERRE 'ML'
# first name: ['Snakin']
# except except : GEROUKI F. SNAKIN 'VV'
# first name: ['Swaine']
# except except : GEROUKI F. SWAINE 'D.'
# first name: ['Swaine']
# try: GEROUKI F. SWAINE 'D.'
# first name: ['Swaine']
# except except : GEROUKI F. SWAINE 'DJ'
# first name: ['Sylaios']
# except except : GEROUKI F. SYLAIOS 'G'
# first name: ['Tang']
# except except : GEROUKI F. TANG 'JC'
# first name: ['Triantafyllou']
# except except : GEROUKI F. TRIANTAFYLLOU 'AG'
# first name: ['Vatalis']
# except except : GEROUKI F. VATALIS 'K.'
# first name: ['Vatalis']
# except except : GEROUKI F. VATALIS 'KI'
# first name: ['Vatalis']
# try: GEROUKI F. VATALIS 'KI'
# first name: ['Xiao']
# except except : GEROUKI F. XIAO 'HY'
# first name: ['Yu']
# except except : GEROUKI F. YU 'HL'
# main name --- i: ['HART']
# first name: ['Hartley']
# except except : HART JD HARTLEY 'W'
# first name: ['Hristopoulos']
# except except : HART JD HRISTOPOULOS 'D.'
# first name: ['ICRCL']
# except except : HART JD ICRCL NONE
# first name: ['James']
# except except : HART JD JAMES 'BR'
# first name: ['Journel']
# except except : HART JD JOURNEL 'A.G.'
# first name: ['Kabata-Pendias']
# except except : HART JD KABATA-PENDIAS 'A.'
# first name: ['Kavouridis']
# except except : HART JD KAVOURIDIS 'K'
# first name: ['Kolovos']
# except except : HART JD KOLOVOS 'N'
# first name: ['Komnitsas']
# except except : HART JD KOMNITSAS 'K'
# first name: ['Komnitsas']
# try: HART JD KOMNITSAS 'K'
# first name: ['Modis']
# except except : HART JD MODIS 'K'
# first name: ['Modis']
# except except : HART JD MODIS 'K.'
# first name: ['Nielsen']
# except except : HART JD NIELSEN 'F.'
# first name: ['Orem']
# except except : HART JD OREM 'W.'
# first name: ['PAVLIDES']
# except except : HART JD PAVLIDES 'SB'
# first name: ['Pentari']
# except except : HART JD PENTARI 'D'
# first name: ['Petrotou']
# except except : HART JD PETROTOU 'A.'
# first name: ['Pills']
# except except : HART JD PILLS 'J.'
# first name: ['Rose']
# except except : HART JD ROSE 'A.'
# first name: ['Sadiq']
# except except : HART JD SADIQ 'M'
# first name: ['Serre']
# except except : HART JD SERRE 'ML'
# first name: ['Snakin']
# except except : HART JD SNAKIN 'VV'
# first name: ['Swaine']
# except except : HART JD SWAINE 'D.'
# first name: ['Swaine']
# try: HART JD SWAINE 'D.'
# first name: ['Swaine']
# except except : HART JD SWAINE 'DJ'
# first name: ['Sylaios']
# except except : HART JD SYLAIOS 'G'
# first name: ['Tang']
# except except : HART JD TANG 'JC'
# first name: ['Triantafyllou']
# except except : HART JD TRIANTAFYLLOU 'AG'
# first name: ['Vatalis']
# except except : HART JD VATALIS 'K.'
# first name: ['Vatalis']
# except except : HART JD VATALIS 'KI'
# first name: ['Vatalis']
# try: HART JD VATALIS 'KI'
# first name: ['Xiao']
# except except : HART JD XIAO 'HY'
# first name: ['Yu']
# except except : HART JD YU 'HL'
# main name --- i: ['Hartley']
# first name: ['Hristopoulos']
# except except : HARTLEY W HRISTOPOULOS 'D.'
# first name: ['ICRCL']
# except except : HARTLEY W ICRCL NONE
# first name: ['James']
# except except : HARTLEY W JAMES 'BR'
# first name: ['Journel']
# except except : HARTLEY W JOURNEL 'A.G.'
# first name: ['Kabata-Pendias']
# except except : HARTLEY W
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-e8b5ccbd468d> in <module>()
#      13         pass
#      14 import tethne.networks as nt
# ---> 15 author_cocitations = nt.authors.author_cocitation(meta_list, 2)
#      16 #print author_cocitations.nodes()
#      17 print author_cocitations.edges()
#
# /Users/ramki/tethne/tethne/networks/authors.pyc in author_cocitation(meta_list, threshold)
#     297                     al_i_str=''.join(map(str,(paper['citations'][i]['aulast']))) #author i's last name
#     298                     print "main name --- i:", paper['citations'][i]['aulast']
# --> 299                     ai_i_str=''.join(map(str,(paper['citations'][i]['auinit']))) #author i's initial
#     300                     author_i_str=al_i_str+delim+ai_i_str#making it a tuple, so that it becomes the key for cocitations dict
#     301                     #print "1:",author_i_str, type(author_i_str)
#
# TypeError: argument 2 to map() must support iteration
# KABATA-PENDIAS 'A.'
# first name: ['Kavouridis']
# except except : HARTLEY W KAVOURIDIS 'K'
# first name: ['Kolovos']
# except except : HARTLEY W KOLOVOS 'N'
# first name: ['Komnitsas']
# except except : HARTLEY W KOMNITSAS 'K'
# first name: ['Komnitsas']
# try: HARTLEY W KOMNITSAS 'K'
# first name: ['Modis']
# except except : HARTLEY W MODIS 'K'
# first name: ['Modis']
# except except : HARTLEY W MODIS 'K.'
# first name: ['Nielsen']
# except except : HARTLEY W NIELSEN 'F.'
# first name: ['Orem']
# except except : HARTLEY W OREM 'W.'
# first name: ['PAVLIDES']
# except except : HARTLEY W PAVLIDES 'SB'
# first name: ['Pentari']
# except except : HARTLEY W PENTARI 'D'
# first name: ['Petrotou']
# except except : HARTLEY W PETROTOU 'A.'
# first name: ['Pills']
# except except : HARTLEY W PILLS 'J.'
# first name: ['Rose']
# except except : HARTLEY W ROSE 'A.'
# first name: ['Sadiq']
# except except : HARTLEY W SADIQ 'M'
# first name: ['Serre']
# except except : HARTLEY W SERRE 'ML'
# first name: ['Snakin']
# except except : HARTLEY W SNAKIN 'VV'
# first name: ['Swaine']
# except except : HARTLEY W SWAINE 'D.'
# first name: ['Swaine']
# try: HARTLEY W SWAINE 'D.'
# first name: ['Swaine']
# except except : HARTLEY W SWAINE 'DJ'
# first name: ['Sylaios']
# except except : HARTLEY W SYLAIOS 'G'
# first name: ['Tang']
# except except : HARTLEY W TANG 'JC'
# first name: ['Triantafyllou']
# except except : HARTLEY W TRIANTAFYLLOU 'AG'
# first name: ['Vatalis']
# except except : HARTLEY W VATALIS 'K.'
# first name: ['Vatalis']
# except except : HARTLEY W VATALIS 'KI'
# first name: ['Vatalis']
# try: HARTLEY W VATALIS 'KI'
# first name: ['Xiao']
# except except : HARTLEY W XIAO 'HY'
# first name: ['Yu']
# except except : HARTLEY W YU 'HL'
# main name --- i: ['Hristopoulos']
# first name: ['ICRCL']
# except except : HRISTOPOULOS D. ICRCL NONE
# first name: ['James']
# except except : HRISTOPOULOS D. JAMES 'BR'
# first name: ['Journel']
# except except : HRISTOPOULOS D. JOURNEL 'A.G.'
# first name: ['Kabata-Pendias']
# except except : HRISTOPOULOS D. KABATA-PENDIAS 'A.'
# first name: ['Kavouridis']
# except except : HRISTOPOULOS D. KAVOURIDIS 'K'
# first name: ['Kolovos']
# except except : HRISTOPOULOS D. KOLOVOS 'N'
# first name: ['Komnitsas']
# except except : HRISTOPOULOS D. KOMNITSAS 'K'
# first name: ['Komnitsas']
# try: HRISTOPOULOS D. KOMNITSAS 'K'
# first name: ['Modis']
# except except : HRISTOPOULOS D. MODIS 'K'
# first name: ['Modis']
# except except : HRISTOPOULOS D. MODIS 'K.'
# first name: ['Nielsen']
# except except : HRISTOPOULOS D. NIELSEN 'F.'
# first name: ['Orem']
# except except : HRISTOPOULOS D. OREM 'W.'
# first name: ['PAVLIDES']
# except except : HRISTOPOULOS D. PAVLIDES 'SB'
# first name: ['Pentari']
# except except : HRISTOPOULOS D. PENTARI 'D'
# first name: ['Petrotou']
# except except : HRISTOPOULOS D. PETROTOU 'A.'
# first name: ['Pills']
# except except : HRISTOPOULOS D. PILLS 'J.'
# first name: ['Rose']
# except except : HRISTOPOULOS D. ROSE 'A.'
# first name: ['Sadiq']
# except except : HRISTOPOULOS D. SADIQ 'M'
# first name: ['Serre']
# except except : HRISTOPOULOS D. SERRE 'ML'
# first name: ['Snakin']
# except except : HRISTOPOULOS D. SNAKIN 'VV'
# first name: ['Swaine']
# except except : HRISTOPOULOS D. SWAINE 'D.'
# first name: ['Swaine']
# try: HRISTOPOULOS D. SWAINE 'D.'
# first name: ['Swaine']
# except except : HRISTOPOULOS D. SWAINE 'DJ'
# first name: ['Sylaios']
# except except : HRISTOPOULOS D. SYLAIOS 'G'
# first name: ['Tang']
# except except : HRISTOPOULOS D. TANG 'JC'
# first name: ['Triantafyllou']
# except except : HRISTOPOULOS D. TRIANTAFYLLOU 'AG'
# first name: ['Vatalis']
# except except : HRISTOPOULOS D. VATALIS 'K.'
# first name: ['Vatalis']
# except except : HRISTOPOULOS D. VATALIS 'KI'
# first name: ['Vatalis']
# try: HRISTOPOULOS D. VATALIS 'KI'
# first name: ['Xiao']
# except except : HRISTOPOULOS D. XIAO 'HY'
# first name: ['Yu']
# except except : HRISTOPOULOS D. YU 'HL'
# main name --- i: ['ICRCL']

# %%
a='5 5' 
b='5 4'
if a!=b:
    print 'yes'
else:
    print 'no'
# Out:
#   File "<ipython-input-5-898ce25640ba>", line 1
#     a=5 5
#         ^
# SyntaxError: invalid syntax
