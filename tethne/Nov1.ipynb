# %%
import tethne.data_struct as ds
# Out:
# hi

# %%
import tethne.readers as rd
filepath = "/Users/ramki/tethne/tethne/testsuite/testin/instituitions_2_types_input.txt"
wos_list = rd.parse_wos(filepath)

for wos in wos_list:
    print wos,'\n'
    print 'its over'

meta_list=rd.wos2meta(wos_list)    
print 'wos_1'
for meta in meta_list:
    print meta , '\n'
# Out:
# comes in readers.parsewos - V5
# wos_dict is
# ...

# %%
import tethne.readers as rd
filepath = "/Users/ramki/tethne/tethne/testsuite/testin/instituitions_2_types_input.txt"
wos_list = rd.parse_wos(filepath)

for wos in wos_list:
   pass

meta_list=rd.wos2meta(wos_list)    
print 'wos_1'
for meta in meta_list:
   pass

import tethne.networks as nt
author_coinst = nt.nx_author_coinstitution(meta_list, 1, 'ayjid', 'atitle', 'date',
                                    'badkey', 'jtitle') 

import tethne.writers as wr
wr.to_gexf(author_coup, "/home/ramki/tethne/tethne/output/author_coupling")
# Out:
# comes in readers.parsewos - V5
# wos_dict is
# ...
